# %%
import numpy as np
import pandas as pd
import datatable as dt
import xgboost as xgb
import shap
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate, cross_val_score, cross_val_predict
from sklearn.metrics import matthews_corrcoef, confusion_matrix, roc_auc_score, classification_report
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline
from sklearn.metrics import recall_score, accuracy_score
from sklearn.impute import KNNImputer

# %%
random_state = 7
cv_method = StratifiedKFold(n_splits=5)

# %%
df = dt.fread('/home/jupyter-dchristiadi85/PhD Project 1/data/testmin_2_6.gz')
df = df.to_pandas()
df.shape
# Out:
# (4965, 596)

# %%
df['aki_1'].fillna(value=0, inplace=True)
df['aki_2'].fillna(value=0, inplace=True)
df['aki_3'].fillna(value=0, inplace=True)

# %%
df['gn'].value_counts()
# Out:
# no                 4508
# igan                184
# anca                 85
# lupus nephritis      45
# membranous           36
# unspecific           29
# fsgs                 27
# mcd                  24
# mp/mcgn              19
# fgn/itg               6
# pign                  2
# Name: gn, dtype: int64

# %%
df.loc[df.gn == 'pign', 'gn'] = 'unspecific'
df.loc[df.gn == 'fgn/itg', 'gn'] = 'unspecific'

# %%
pd.set_option('display.max_rows', 600)
percent_missing = df.isnull().sum()*100 / len(df)
missing_df = pd.DataFrame({'column_name': df.columns, 'percent_miss': percent_missing})
missing_df.sort_values(by='percent_miss', ascending=False)
# Out:
#                                                              column_name  \
# timedprotein__sum_values                        timedprotein__sum_values
# timedprotein__minimum                              timedprotein__minimum
# timedprotein__maximum                              timedprotein__maximum
# timedprotein__root_mean_square            timedprotein__root_mean_square
# timedprotein__variance                            timedprotein__variance
# timedprotein__standard_deviation        timedprotein__standard_deviation
# timedprotein__length                                timedprotein__length
# timedprotein__mean                                    timedprotein__mean
# timedprotein__median                                timedprotein__median
# albcreat_ratio__length                            albcreat_ratio__length
# albcreat_ratio__maximum                          albcreat_ratio__maximum
# albcreat_ratio__root_mean_square        albcreat_ratio__root_mean_square
# albcreat_ratio__variance                        albcreat_ratio__variance
# albcreat_ratio__standard_deviation    albcreat_ratio__standard_deviation
# albcreat_ratio__minimum                          albcreat_ratio__minimum
# albcreat_ratio__mean                                albcreat_ratio__mean
# albcreat_ratio__median                            albcreat_ratio__median
# albcreat_ratio__sum_values                    albcreat_ratio__sum_values
# death.y                                                          death.y
# esr__variance                                              esr__variance
# esr__sum_values                                          esr__sum_values
# esr__median                                                  esr__median
# esr__mean                                                      esr__mean
# esr__length                                                  esr__length
# esr__standard_deviation                          esr__standard_deviation
# esr__minimum                                                esr__minimum
# esr__root_mean_square                              esr__root_mean_square
# esr__maximum                                                esr__maximum
# tsh__length                                                  tsh__length
# tsh__minimum                                                tsh__minimum
# tsh__maximum                                                tsh__maximum
# tsh__root_mean_square                              tsh__root_mean_square
# tsh__standard_deviation                          tsh__standard_deviation
# tsh__variance                                              tsh__variance
# tsh__mean                                                      tsh__mean
# tsh__median                                                  tsh__median
# tsh__sum_values                                          tsh__sum_values
# protcreat_ratio__maximum                        protcreat_ratio__maximum
# protcreat_ratio__sum_values                  protcreat_ratio__sum_values
# protcreat_ratio__root_mean_square      protcreat_ratio__root_mean_square
# protcreat_ratio__minimum                        protcreat_ratio__minimum
# protcreat_ratio__length                          protcreat_ratio__length
# protcreat_ratio__mean                              protcreat_ratio__mean
# protcreat_ratio__median                          protcreat_ratio__median
# protcreat_ratio__variance                      protcreat_ratio__variance
# protcreat_ratio__standard_deviation  protcreat_ratio__standard_deviation
# hba1c__variance                                          hba1c__variance
# hba1c__sum_values                                      hba1c__sum_values
# hba1c__median                                              hba1c__median
# hba1c__mean                                                  hba1c__mean
# hba1c__length                                              hba1c__length
# hba1c__standard_deviation                      hba1c__standard_deviation
# hba1c__root_mean_square                          hba1c__root_mean_square
# hba1c__maximum                                            hba1c__maximum
# hba1c__minimum                                            hba1c__minimum
# diff_hr__root_mean_square                      diff_hr__root_mean_square
# diff_hr__variance                                      diff_hr__variance
# diff_hr__sum_values                                  diff_hr__sum_values
# diff_hr__median                                          diff_hr__median
# diff_hr__maximum                                        diff_hr__maximum
# diff_hr__minimum                                        diff_hr__minimum
# diff_hr__length                                          diff_hr__length
# diff_hr__standard_deviation                  diff_hr__standard_deviation
# diff_hr__mean                                              diff_hr__mean
# sta_hr__length                                            sta_hr__length
# sta_hr__median                                            sta_hr__median
# sta_hr__mean                                                sta_hr__mean
# sta_hr__minimum                                          sta_hr__minimum
# sta_hr__maximum                                          sta_hr__maximum
# sta_hr__root_mean_square                        sta_hr__root_mean_square
# sta_hr__variance                                        sta_hr__variance
# sta_hr__standard_deviation                    sta_hr__standard_deviation
# sta_hr__sum_values                                    sta_hr__sum_values
# iron__minimum                                              iron__minimum
# iron__sum_values                                        iron__sum_values
# iron__maximum                                              iron__maximum
# iron__root_mean_square                            iron__root_mean_square
# iron__variance                                            iron__variance
# iron__standard_deviation                        iron__standard_deviation
# iron__length                                                iron__length
# iron__mean                                                    iron__mean
# iron__median                                                iron__median
# diff_dia__median                                        diff_dia__median
# diff_dia__length                                        diff_dia__length
# diff_dia__standard_deviation                diff_dia__standard_deviation
# diff_dia__variance                                    diff_dia__variance
# diff_dia__root_mean_square                    diff_dia__root_mean_square
# diff_dia__maximum                                      diff_dia__maximum
# diff_dia__minimum                                      diff_dia__minimum
# diff_dia__mean                                            diff_dia__mean
# diff_dia__sum_values                                diff_dia__sum_values
# diff_sys__minimum                                      diff_sys__minimum
# diff_sys__maximum                                      diff_sys__maximum
# diff_sys__variance                                    diff_sys__variance
# diff_sys__standard_deviation                diff_sys__standard_deviation
# diff_sys__length                                        diff_sys__length
# diff_sys__mean                                            diff_sys__mean
# diff_sys__median                                        diff_sys__median
# diff_sys__sum_values                                diff_sys__sum_values
# diff_sys__root_mean_square                    diff_sys__root_mean_square
# sit_hr__maximum                                          sit_hr__maximum
# sit_hr__variance                                        sit_hr__variance
# sit_hr__minimum                                          sit_hr__minimum
# sit_hr__sum_values                                    sit_hr__sum_values
# sit_hr__root_mean_square                        sit_hr__root_mean_square
# sit_hr__length                                            sit_hr__length
# sit_hr__standard_deviation                    sit_hr__standard_deviation
# sit_hr__mean                                                sit_hr__mean
# sit_hr__median                                            sit_hr__median
# tsat__maximum                                              tsat__maximum
# tsat__root_mean_square                            tsat__root_mean_square
# tsat__variance                                            tsat__variance
# tsat__standard_deviation                        tsat__standard_deviation
# tsat__length                                                tsat__length
# tsat__mean                                                    tsat__mean
# tsat__median                                                tsat__median
# tsat__minimum                                              tsat__minimum
# tsat__sum_values                                        tsat__sum_values
# transferrin__minimum                                transferrin__minimum
# transferrin__sum_values                          transferrin__sum_values
# transferrin__maximum                                transferrin__maximum
# transferrin__root_mean_square              transferrin__root_mean_square
# transferrin__variance                              transferrin__variance
# transferrin__standard_deviation          transferrin__standard_deviation
# transferrin__mean                                      transferrin__mean
# transferrin__median                                  transferrin__median
# transferrin__length                                  transferrin__length
# eskd.y                                                            eskd.y
# ferritin__sum_values                                ferritin__sum_values
# ferritin__minimum                                      ferritin__minimum
# ferritin__mean                                            ferritin__mean
# ferritin__length                                        ferritin__length
# ferritin__standard_deviation                ferritin__standard_deviation
# ferritin__variance                                    ferritin__variance
# ferritin__root_mean_square                    ferritin__root_mean_square
# ferritin__maximum                                      ferritin__maximum
# ferritin__median                                        ferritin__median
# ldl__sum_values                                          ldl__sum_values
# ldl__median                                                  ldl__median
# ldl__minimum                                                ldl__minimum
# ldl__maximum                                                ldl__maximum
# ldl__root_mean_square                              ldl__root_mean_square
# ldl__variance                                              ldl__variance
# ldl__standard_deviation                          ldl__standard_deviation
# ldl__length                                                  ldl__length
# ldl__mean                                                      ldl__mean
# hdl__sum_values                                          hdl__sum_values
# hdl__median                                                  hdl__median
# hdl__mean                                                      hdl__mean
# hdl__length                                                  hdl__length
# hdl__standard_deviation                          hdl__standard_deviation
# hdl__variance                                              hdl__variance
# hdl__root_mean_square                              hdl__root_mean_square
# hdl__maximum                                                hdl__maximum
# hdl__minimum                                                hdl__minimum
# bmi__minimum                                                bmi__minimum
# bmi__median                                                  bmi__median
# bmi__sum_values                                          bmi__sum_values
# bmi__mean                                                      bmi__mean
# bmi__length                                                  bmi__length
# bmi__standard_deviation                          bmi__standard_deviation
# bmi__variance                                              bmi__variance
# bmi__root_mean_square                              bmi__root_mean_square
# bmi__maximum                                                bmi__maximum
# height__standard_deviation                    height__standard_deviation
# height__median                                            height__median
# height__root_mean_square                        height__root_mean_square
# height__maximum                                          height__maximum
# height__minimum                                          height__minimum
# height__length                                            height__length
# height__mean                                                height__mean
# height__variance                                        height__variance
# height__sum_values                                    height__sum_values
# crp__root_mean_square                              crp__root_mean_square
# crp__minimum                                                crp__minimum
# crp__maximum                                                crp__maximum
# crp__variance                                              crp__variance
# crp__standard_deviation                          crp__standard_deviation
# crp__length                                                  crp__length
# crp__median                                                  crp__median
# crp__sum_values                                          crp__sum_values
# crp__mean                                                      crp__mean
# urate__median                                              urate__median
# urate__sum_values                                      urate__sum_values
# urate__length                                              urate__length
# urate__mean                                                  urate__mean
# urate__standard_deviation                      urate__standard_deviation
# urate__variance                                          urate__variance
# urate__root_mean_square                          urate__root_mean_square
# urate__maximum                                            urate__maximum
# urate__minimum                                            urate__minimum
# pth__minimum                                                pth__minimum
# pth__root_mean_square                              pth__root_mean_square
# pth__variance                                              pth__variance
# pth__standard_deviation                          pth__standard_deviation
# pth__length                                                  pth__length
# pth__mean                                                      pth__mean
# pth__median                                                  pth__median
# pth__sum_values                                          pth__sum_values
# pth__maximum                                                pth__maximum
# sta_sys__mean                                              sta_sys__mean
# sta_sys__median                                          sta_sys__median
# sta_sys__sum_values                                  sta_sys__sum_values
# sta_dia__minimum                                        sta_dia__minimum
# sta_dia__maximum                                        sta_dia__maximum
# sta_dia__root_mean_square                      sta_dia__root_mean_square
# sta_dia__variance                                      sta_dia__variance
# sta_dia__median                                          sta_dia__median
# sta_sys__length                                          sta_sys__length
# sta_sys__standard_deviation                  sta_sys__standard_deviation
# sta_sys__variance                                      sta_sys__variance
# sta_sys__root_mean_square                      sta_sys__root_mean_square
# sta_sys__maximum                                        sta_sys__maximum
# sta_sys__minimum                                        sta_sys__minimum
# sta_dia__sum_values                                  sta_dia__sum_values
# sta_dia__mean                                              sta_dia__mean
# sta_dia__standard_deviation                  sta_dia__standard_deviation
# sta_dia__length                                          sta_dia__length
# sit_dia__maximum                                        sit_dia__maximum
# sit_dia__standard_deviation                  sit_dia__standard_deviation
# sit_dia__variance                                      sit_dia__variance
# sit_dia__root_mean_square                      sit_dia__root_mean_square
# sit_dia__minimum                                        sit_dia__minimum
# sit_dia__mean                                              sit_dia__mean
# sit_dia__median                                          sit_dia__median
# sit_dia__sum_values                                  sit_dia__sum_values
# sit_sys__sum_values                                  sit_sys__sum_values
# sit_sys__median                                          sit_sys__median
# sit_sys__mean                                              sit_sys__mean
# sit_sys__length                                          sit_sys__length
# sit_sys__standard_deviation                  sit_sys__standard_deviation
# sit_sys__variance                                      sit_sys__variance
# sit_sys__root_mean_square                      sit_sys__root_mean_square
# sit_sys__maximum                                        sit_sys__maximum
# sit_sys__minimum                                        sit_sys__minimum
# sit_dia__length                                          sit_dia__length
# rdw__sum_values                                          rdw__sum_values
# rdw__median                                                  rdw__median
# rdw__mean                                                      rdw__mean
# rdw__length                                                  rdw__length
# rdw__standard_deviation                          rdw__standard_deviation
# rdw__variance                                              rdw__variance
# rdw__minimum                                                rdw__minimum
# rdw__maximum                                                rdw__maximum
# rdw__root_mean_square                              rdw__root_mean_square
# weight__maximum                                          weight__maximum
# weight__sum_values                                    weight__sum_values
# weight__median                                            weight__median
# weight__mean                                                weight__mean
# weight__length                                            weight__length
# weight__variance                                        weight__variance
# weight__root_mean_square                        weight__root_mean_square
# weight__standard_deviation                    weight__standard_deviation
# weight__minimum                                          weight__minimum
# triglycerides__minimum                            triglycerides__minimum
# triglycerides__maximum                            triglycerides__maximum
# triglycerides__sum_values                      triglycerides__sum_values
# triglycerides__median                              triglycerides__median
# triglycerides__mean                                  triglycerides__mean
# triglycerides__standard_deviation      triglycerides__standard_deviation
# triglycerides__root_mean_square          triglycerides__root_mean_square
# triglycerides__variance                          triglycerides__variance
# triglycerides__length                              triglycerides__length
# cholesterol__length                                  cholesterol__length
# cholesterol__standard_deviation          cholesterol__standard_deviation
# cholesterol__mean                                      cholesterol__mean
# cholesterol__median                                  cholesterol__median
# cholesterol__sum_values                          cholesterol__sum_values
# cholesterol__variance                              cholesterol__variance
# cholesterol__root_mean_square              cholesterol__root_mean_square
# cholesterol__maximum                                cholesterol__maximum
# cholesterol__minimum                                cholesterol__minimum
# globulin__mean                                            globulin__mean
# globulin__sum_values                                globulin__sum_values
# globulin__median                                        globulin__median
# globulin__length                                        globulin__length
# globulin__standard_deviation                globulin__standard_deviation
# globulin__variance                                    globulin__variance
# globulin__root_mean_square                    globulin__root_mean_square
# globulin__maximum                                      globulin__maximum
# globulin__minimum                                      globulin__minimum
# protein__maximum                                        protein__maximum
# protein__root_mean_square                      protein__root_mean_square
# protein__length                                          protein__length
# protein__standard_deviation                  protein__standard_deviation
# protein__variance                                      protein__variance
# protein__mean                                              protein__mean
# protein__median                                          protein__median
# protein__minimum                                        protein__minimum
# protein__sum_values                                  protein__sum_values
# magnesium__maximum                                    magnesium__maximum
# magnesium__root_mean_square                  magnesium__root_mean_square
# magnesium__sum_values                              magnesium__sum_values
# magnesium__median                                      magnesium__median
# magnesium__mean                                          magnesium__mean
# magnesium__length                                      magnesium__length
# magnesium__minimum                                    magnesium__minimum
# magnesium__standard_deviation              magnesium__standard_deviation
# magnesium__variance                                  magnesium__variance
# ggt__root_mean_square                              ggt__root_mean_square
# ggt__minimum                                                ggt__minimum
# ggt__maximum                                                ggt__maximum
# ggt__mean                                                      ggt__mean
# ggt__length                                                  ggt__length
# ggt__standard_deviation                          ggt__standard_deviation
# ggt__variance                                              ggt__variance
# ggt__sum_values                                          ggt__sum_values
# ggt__median                                                  ggt__median
# bilirubin__length                                      bilirubin__length
# bilirubin__sum_values                              bilirubin__sum_values
# bilirubin__maximum                                    bilirubin__maximum
# bilirubin__root_mean_square                  bilirubin__root_mean_square
# bilirubin__variance                                  bilirubin__variance
# bilirubin__standard_deviation              bilirubin__standard_deviation
# bilirubin__mean                                          bilirubin__mean
# bilirubin__median                                      bilirubin__median
# bilirubin__minimum                                    bilirubin__minimum
# alt__sum_values                                          alt__sum_values
# alt__median                                                  alt__median
# alt__minimum                                                alt__minimum
# alt__maximum                                                alt__maximum
# alt__root_mean_square                              alt__root_mean_square
# alt__mean                                                      alt__mean
# alt__length                                                  alt__length
# alt__standard_deviation                          alt__standard_deviation
# alt__variance                                              alt__variance
# bicarbonate__variance                              bicarbonate__variance
# bicarbonate__standard_deviation          bicarbonate__standard_deviation
# bicarbonate__minimum                                bicarbonate__minimum
# bicarbonate__root_mean_square              bicarbonate__root_mean_square
# bicarbonate__maximum                                bicarbonate__maximum
# bicarbonate__sum_values                          bicarbonate__sum_values
# bicarbonate__median                                  bicarbonate__median
# bicarbonate__mean                                      bicarbonate__mean
# bicarbonate__length                                  bicarbonate__length
# basophils__variance                                  basophils__variance
# basophils__root_mean_square                  basophils__root_mean_square
# basophils__length                                      basophils__length
# basophils__minimum                                    basophils__minimum
# basophils__maximum                                    basophils__maximum
# basophils__standard_deviation              basophils__standard_deviation
# basophils__mean                                          basophils__mean
# basophils__sum_values                              basophils__sum_values
# basophils__median                                      basophils__median
# eosinophils__standard_deviation          eosinophils__standard_deviation
# eosinophils__median                                  eosinophils__median
# eosinophils__mean                                      eosinophils__mean
# eosinophils__length                                  eosinophils__length
# eosinophils__sum_values                          eosinophils__sum_values
# eosinophils__variance                              eosinophils__variance
# eosinophils__maximum                                eosinophils__maximum
# eosinophils__minimum                                eosinophils__minimum
# eosinophils__root_mean_square              eosinophils__root_mean_square
# lymphocytes__root_mean_square              lymphocytes__root_mean_square
# lymphocytes__median                                  lymphocytes__median
# lymphocytes__mean                                      lymphocytes__mean
# lymphocytes__length                                  lymphocytes__length
# lymphocytes__standard_deviation          lymphocytes__standard_deviation
# lymphocytes__variance                              lymphocytes__variance
# lymphocytes__minimum                                lymphocytes__minimum
# lymphocytes__maximum                                lymphocytes__maximum
# neutrophils__mean                                      neutrophils__mean
# neutrophils__median                                  neutrophils__median
# neutrophils__sum_values                          neutrophils__sum_values
# neutrophils__length                                  neutrophils__length
# monocytes__minimum                                    monocytes__minimum
# monocytes__maximum                                    monocytes__maximum
# lymphocytes__sum_values                          lymphocytes__sum_values
# neutrophils__root_mean_square              neutrophils__root_mean_square
# neutrophils__standard_deviation          neutrophils__standard_deviation
# neutrophils__variance                              neutrophils__variance
# neutrophils__maximum                                neutrophils__maximum
# neutrophils__minimum                                neutrophils__minimum
# monocytes__sum_values                              monocytes__sum_values
# monocytes__median                                      monocytes__median
# monocytes__mean                                          monocytes__mean
# monocytes__length                                      monocytes__length
# monocytes__standard_deviation              monocytes__standard_deviation
# monocytes__variance                                  monocytes__variance
# monocytes__root_mean_square                  monocytes__root_mean_square
# mcv__standard_deviation                          mcv__standard_deviation
# mcv__variance                                              mcv__variance
# mcv__root_mean_square                              mcv__root_mean_square
# mcv__maximum                                                mcv__maximum
# mcv__minimum                                                mcv__minimum
# mcv__median                                                  mcv__median
# mcv__mean                                                      mcv__mean
# rbc__sum_values                                          rbc__sum_values
# rbc__median                                                  rbc__median
# rbc__mean                                                      rbc__mean
# rbc__length                                                  rbc__length
# rbc__standard_deviation                          rbc__standard_deviation
# rbc__variance                                              rbc__variance
# rbc__root_mean_square                              rbc__root_mean_square
# rbc__maximum                                                rbc__maximum
# rbc__minimum                                                rbc__minimum
# mcv__length                                                  mcv__length
# mch__length                                                  mch__length
# mch__sum_values                                          mch__sum_values
# mch__minimum                                                mch__minimum
# mcv__sum_values                                          mcv__sum_values
# mch__median                                                  mch__median
# mch__mean                                                      mch__mean
# mch__standard_deviation                          mch__standard_deviation
# mch__variance                                              mch__variance
# mch__maximum                                                mch__maximum
# mch__root_mean_square                              mch__root_mean_square
# mchc__median                                                mchc__median
# mchc__variance                                            mchc__variance
# mchc__minimum                                              mchc__minimum
# mchc__sum_values                                        mchc__sum_values
# mchc__root_mean_square                            mchc__root_mean_square
# mchc__maximum                                              mchc__maximum
# mchc__standard_deviation                        mchc__standard_deviation
# mchc__length                                                mchc__length
# mchc__mean                                                    mchc__mean
# haematocrit__sum_values                          haematocrit__sum_values
# haematocrit__minimum                                haematocrit__minimum
# haematocrit__median                                  haematocrit__median
# haematocrit__mean                                      haematocrit__mean
# haematocrit__length                                  haematocrit__length
# haematocrit__standard_deviation          haematocrit__standard_deviation
# haematocrit__variance                              haematocrit__variance
# haematocrit__root_mean_square              haematocrit__root_mean_square
# haematocrit__maximum                                haematocrit__maximum
# caphos_product__length                            caphos_product__length
# caphos_product__minimum                          caphos_product__minimum
# caphos_product__maximum                          caphos_product__maximum
# caphos_product__root_mean_square        caphos_product__root_mean_square
# caphos_product__variance                        caphos_product__variance
# caphos_product__standard_deviation    caphos_product__standard_deviation
# caphos_product__mean                                caphos_product__mean
# caphos_product__median                            caphos_product__median
# caphos_product__sum_values                    caphos_product__sum_values
# phosphate__variance                                  phosphate__variance
# phosphate__maximum                                    phosphate__maximum
# phosphate__root_mean_square                  phosphate__root_mean_square
# phosphate__sum_values                              phosphate__sum_values
# phosphate__standard_deviation              phosphate__standard_deviation
# phosphate__length                                      phosphate__length
# phosphate__mean                                          phosphate__mean
# phosphate__minimum                                    phosphate__minimum
# phosphate__median                                      phosphate__median
# glucose__length                                          glucose__length
# glucose__mean                                              glucose__mean
# glucose__variance                                      glucose__variance
# glucose__sum_values                                  glucose__sum_values
# glucose__median                                          glucose__median
# glucose__standard_deviation                  glucose__standard_deviation
# glucose__maximum                                        glucose__maximum
# glucose__root_mean_square                      glucose__root_mean_square
# glucose__minimum                                        glucose__minimum
# calcium__sum_values                                  calcium__sum_values
# calcium__median                                          calcium__median
# calcium__mean                                              calcium__mean
# calcium__length                                          calcium__length
# calcium__standard_deviation                  calcium__standard_deviation
# calcium__variance                                      calcium__variance
# calcium__root_mean_square                      calcium__root_mean_square
# calcium__maximum                                        calcium__maximum
# calcium__minimum                                        calcium__minimum
# chloride__root_mean_square                    chloride__root_mean_square
# chloride__variance                                    chloride__variance
# chloride__standard_deviation                chloride__standard_deviation
# chloride__length                                        chloride__length
# chloride__minimum                                      chloride__minimum
# chloride__sum_values                                chloride__sum_values
# chloride__median                                        chloride__median
# chloride__mean                                            chloride__mean
# chloride__maximum                                      chloride__maximum
# alkphos__root_mean_square                      alkphos__root_mean_square
# alkphos__sum_values                                  alkphos__sum_values
# alkphos__median                                          alkphos__median
# alkphos__mean                                              alkphos__mean
# alkphos__length                                          alkphos__length
# alkphos__standard_deviation                  alkphos__standard_deviation
# alkphos__variance                                      alkphos__variance
# alkphos__minimum                                        alkphos__minimum
# alkphos__maximum                                        alkphos__maximum
# platelet__median                                        platelet__median
# platelet__standard_deviation                platelet__standard_deviation
# platelet__length                                        platelet__length
# platelet__variance                                    platelet__variance
# platelet__root_mean_square                    platelet__root_mean_square
# platelet__maximum                                      platelet__maximum
# platelet__minimum                                      platelet__minimum
# platelet__mean                                            platelet__mean
# platelet__sum_values                                platelet__sum_values
# wcc__median                                                  wcc__median
# wcc__variance                                              wcc__variance
# wcc__root_mean_square                              wcc__root_mean_square
# wcc__standard_deviation                          wcc__standard_deviation
# wcc__length                                                  wcc__length
# wcc__sum_values                                          wcc__sum_values
# wcc__mean                                                      wcc__mean
# wcc__minimum                                                wcc__minimum
# wcc__maximum                                                wcc__maximum
# albumin__minimum                                        albumin__minimum
# albumin__sum_values                                  albumin__sum_values
# albumin__maximum                                        albumin__maximum
# albumin__variance                                      albumin__variance
# albumin__standard_deviation                  albumin__standard_deviation
# albumin__length                                          albumin__length
# albumin__mean                                              albumin__mean
# albumin__median                                          albumin__median
# albumin__root_mean_square                      albumin__root_mean_square
# haemoglobin__standard_deviation          haemoglobin__standard_deviation
# haemoglobin__minimum                                haemoglobin__minimum
# haemoglobin__maximum                                haemoglobin__maximum
# haemoglobin__root_mean_square              haemoglobin__root_mean_square
# haemoglobin__variance                              haemoglobin__variance
# haemoglobin__sum_values                          haemoglobin__sum_values
# haemoglobin__length                                  haemoglobin__length
# haemoglobin__mean                                      haemoglobin__mean
# haemoglobin__median                                  haemoglobin__median
# sodium__length                                            sodium__length
# sodium__mean                                                sodium__mean
# sodium__median                                            sodium__median
# sodium__variance                                        sodium__variance
# sodium__standard_deviation                    sodium__standard_deviation
# sodium__root_mean_square                        sodium__root_mean_square
# sodium__minimum                                          sodium__minimum
# sodium__sum_values                                    sodium__sum_values
# sodium__maximum                                          sodium__maximum
# potassium__standard_deviation              potassium__standard_deviation
# potassium__mean                                          potassium__mean
# potassium__root_mean_square                  potassium__root_mean_square
# potassium__sum_values                              potassium__sum_values
# potassium__median                                      potassium__median
# potassium__variance                                  potassium__variance
# potassium__length                                      potassium__length
# potassium__minimum                                    potassium__minimum
# potassium__maximum                                    potassium__maximum
# urea__maximum                                              urea__maximum
# ureacreat_ratio__minimum                        ureacreat_ratio__minimum
# ureacreat_ratio__maximum                        ureacreat_ratio__maximum
# ureacreat_ratio__root_mean_square      ureacreat_ratio__root_mean_square
# ureacreat_ratio__variance                      ureacreat_ratio__variance
# ureacreat_ratio__standard_deviation  ureacreat_ratio__standard_deviation
# ureacreat_ratio__length                          ureacreat_ratio__length
# ureacreat_ratio__mean                              ureacreat_ratio__mean
# ureacreat_ratio__median                          ureacreat_ratio__median
# ureacreat_ratio__sum_values                  ureacreat_ratio__sum_values
# urea__minimum                                              urea__minimum
# urea__root_mean_square                            urea__root_mean_square
# urea__standard_deviation                        urea__standard_deviation
# urea__length                                                urea__length
# urea__mean                                                    urea__mean
# urea__median                                                urea__median
# urea__sum_values                                        urea__sum_values
# urea__variance                                            urea__variance
# egfr__standard_deviation                        egfr__standard_deviation
# egfr__variance                                            egfr__variance
# egfr__root_mean_square                            egfr__root_mean_square
# egfr__maximum                                              egfr__maximum
# egfr__minimum                                              egfr__minimum
# egfr__length                                                egfr__length
# egfr__mean                                                    egfr__mean
# egfr__median                                                egfr__median
# egfr__sum_values                                        egfr__sum_values
# creatinine__sum_values                            creatinine__sum_values
# creatinine__median                                    creatinine__median
# creatinine__minimum                                  creatinine__minimum
# creatinine__maximum                                  creatinine__maximum
# creatinine__root_mean_square                creatinine__root_mean_square
# creatinine__variance                                creatinine__variance
# creatinine__standard_deviation            creatinine__standard_deviation
# creatinine__mean                                        creatinine__mean
# creatinine__length                                    creatinine__length
# cat4.5                                                            cat4.5
# cat2.5                                                            cat2.5
# cat3                                                                cat3
# cat3.5                                                            cat3.5
# cat4                                                                cat4
# cat6                                                                cat6
# cat5                                                                cat5
# cat5.5                                                            cat5.5
# cat1.5                                                            cat1.5
# cat6.5                                                            cat6.5
# cat7                                                                cat7
# cat7.5                                                            cat7.5
# cat2                                                                cat2
# id                                                                    id
# cat1                                                                cat1
# cat0.5                                                            cat0.5
# age.init                                                        age.init
# egfr.y                                                            egfr.y
# value_egfr_init                                          value_egfr_init
# gender                                                            gender
# gn                                                                    gn
# dkd                                                                  dkd
# htn                                                                  htn
# aki_3                                                              aki_3
# aki_2                                                              aki_2
# aki_1                                                              aki_1
# cat8                                                                cat8
#
#                                      percent_miss
# timedprotein__sum_values                95.709970
# timedprotein__minimum                   95.709970
# timedprotein__maximum                   95.709970
# timedprotein__root_mean_square          95.709970
# timedprotein__variance                  95.709970
# timedprotein__standard_deviation        95.709970
# timedprotein__length                    95.709970
# timedprotein__mean                      95.709970
# timedprotein__median                    95.709970
# albcreat_ratio__length                  89.989930
# albcreat_ratio__maximum                 89.989930
# albcreat_ratio__root_mean_square        89.989930
# albcreat_ratio__variance                89.989930
# albcreat_ratio__standard_deviation      89.989930
# albcreat_ratio__minimum                 89.989930
# albcreat_ratio__mean                    89.989930
# albcreat_ratio__median                  89.989930
# albcreat_ratio__sum_values              89.989930
# death.y                                 83.564955
# esr__variance                           81.409869
# esr__sum_values                         81.409869
# esr__median                             81.409869
# esr__mean                               81.409869
# esr__length                             81.409869
# esr__standard_deviation                 81.409869
# esr__minimum                            81.409869
# esr__root_mean_square                   81.409869
# esr__maximum                            81.409869
# tsh__length                             75.005035
# tsh__minimum                            75.005035
# tsh__maximum                            75.005035
# tsh__root_mean_square                   75.005035
# tsh__standard_deviation                 75.005035
# tsh__variance                           75.005035
# tsh__mean                               75.005035
# tsh__median                             75.005035
# tsh__sum_values                         75.005035
# protcreat_ratio__maximum                74.823766
# protcreat_ratio__sum_values             74.823766
# protcreat_ratio__root_mean_square       74.823766
# protcreat_ratio__minimum                74.823766
# protcreat_ratio__length                 74.823766
# protcreat_ratio__mean                   74.823766
# protcreat_ratio__median                 74.823766
# protcreat_ratio__variance               74.823766
# protcreat_ratio__standard_deviation     74.823766
# hba1c__variance                         66.445116
# hba1c__sum_values                       66.445116
# hba1c__median                           66.445116
# ...
# protein__sum_values                     37.603223
# magnesium__maximum                      37.341390
# magnesium__root_mean_square             37.341390
# magnesium__sum_values                   37.341390
# magnesium__median                       37.341390
# magnesium__mean                         37.341390
# magnesium__length                       37.341390
# magnesium__minimum                      37.341390
# magnesium__standard_deviation           37.341390
# magnesium__variance                     37.341390
# ggt__root_mean_square                   36.938570
# ggt__minimum                            36.938570
# ggt__maximum                            36.938570
# ggt__mean                               36.938570
# ggt__length                             36.938570
# ggt__standard_deviation                 36.938570
# ggt__variance                           36.938570
# ggt__sum_values                         36.938570
# ggt__median                             36.938570
# bilirubin__length                       36.938570
# bilirubin__sum_values                   36.938570
# bilirubin__maximum                      36.938570
# bilirubin__root_mean_square             36.938570
# bilirubin__variance                     36.938570
# bilirubin__standard_deviation           36.938570
# bilirubin__mean                         36.938570
# bilirubin__median                       36.938570
# bilirubin__minimum                      36.938570
# alt__sum_values                         36.898288
# alt__median                             36.898288
# alt__minimum                            36.898288
# alt__maximum                            36.898288
# alt__root_mean_square                   36.898288
# alt__mean                               36.898288
# alt__length                             36.898288
# alt__standard_deviation                 36.898288
# alt__variance                           36.898288
# bicarbonate__variance                   36.273917
# bicarbonate__standard_deviation         36.273917
# bicarbonate__minimum                    36.273917
# bicarbonate__root_mean_square           36.273917
# bicarbonate__maximum                    36.273917
# bicarbonate__sum_values                 36.273917
# bicarbonate__median                     36.273917
# bicarbonate__mean                       36.273917
# bicarbonate__length                     36.273917
# basophils__variance                     34.400806
# basophils__root_mean_square             34.400806
# basophils__length                       34.400806
# basophils__minimum                      34.400806
# basophils__maximum                      34.400806
# basophils__standard_deviation           34.400806
# basophils__mean                         34.400806
# basophils__sum_values                   34.400806
# basophils__median                       34.400806
# eosinophils__standard_deviation         34.380665
# eosinophils__median                     34.380665
# eosinophils__mean                       34.380665
# eosinophils__length                     34.380665
# eosinophils__sum_values                 34.380665
# eosinophils__variance                   34.380665
# eosinophils__maximum                    34.380665
# eosinophils__minimum                    34.380665
# eosinophils__root_mean_square           34.380665
# lymphocytes__root_mean_square           33.917422
# lymphocytes__median                     33.917422
# lymphocytes__mean                       33.917422
# lymphocytes__length                     33.917422
# lymphocytes__standard_deviation         33.917422
# lymphocytes__variance                   33.917422
# lymphocytes__minimum                    33.917422
# lymphocytes__maximum                    33.917422
# neutrophils__mean                       33.917422
# neutrophils__median                     33.917422
# neutrophils__sum_values                 33.917422
# neutrophils__length                     33.917422
# monocytes__minimum                      33.917422
# monocytes__maximum                      33.917422
# lymphocytes__sum_values                 33.917422
# neutrophils__root_mean_square           33.917422
# neutrophils__standard_deviation         33.917422
# neutrophils__variance                   33.917422
# neutrophils__maximum                    33.917422
# neutrophils__minimum                    33.917422
# monocytes__sum_values                   33.917422
# monocytes__median                       33.917422
# monocytes__mean                         33.917422
# monocytes__length                       33.917422
# monocytes__standard_deviation           33.917422
# monocytes__variance                     33.917422
# monocytes__root_mean_square             33.917422
# mcv__standard_deviation                 33.897281
# mcv__variance                           33.897281
# mcv__root_mean_square                   33.897281
# mcv__maximum                            33.897281
# mcv__minimum                            33.897281
# mcv__median                             33.897281
# mcv__mean                               33.897281
# rbc__sum_values                         33.897281
# rbc__median                             33.897281
# rbc__mean                               33.897281
# rbc__length                             33.897281
# rbc__standard_deviation                 33.897281
# rbc__variance                           33.897281
# rbc__root_mean_square                   33.897281
# rbc__maximum                            33.897281
# rbc__minimum                            33.897281
# mcv__length                             33.897281
# mch__length                             33.897281
# mch__sum_values                         33.897281
# mch__minimum                            33.897281
# mcv__sum_values                         33.897281
# mch__median                             33.897281
# mch__mean                               33.897281
# mch__standard_deviation                 33.897281
# mch__variance                           33.897281
# mch__maximum                            33.897281
# mch__root_mean_square                   33.897281
# mchc__median                            33.877140
# mchc__variance                          33.877140
# mchc__minimum                           33.877140
# mchc__sum_values                        33.877140
# mchc__root_mean_square                  33.877140
# mchc__maximum                           33.877140
# mchc__standard_deviation                33.877140
# mchc__length                            33.877140
# mchc__mean                              33.877140
# haematocrit__sum_values                 33.856999
# haematocrit__minimum                    33.856999
# haematocrit__median                     33.856999
# haematocrit__mean                       33.856999
# haematocrit__length                     33.856999
# haematocrit__standard_deviation         33.856999
# haematocrit__variance                   33.856999
# haematocrit__root_mean_square           33.856999
# haematocrit__maximum                    33.856999
# caphos_product__length                  15.810675
# caphos_product__minimum                 15.810675
# caphos_product__maximum                 15.810675
# caphos_product__root_mean_square        15.810675
# caphos_product__variance                15.810675
# caphos_product__standard_deviation      15.810675
# caphos_product__mean                    15.810675
# caphos_product__median                  15.810675
# caphos_product__sum_values              15.810675
# phosphate__variance                     15.770393
# phosphate__maximum                      15.770393
# phosphate__root_mean_square             15.770393
# phosphate__sum_values                   15.770393
# phosphate__standard_deviation           15.770393
# phosphate__length                       15.770393
# phosphate__mean                         15.770393
# phosphate__minimum                      15.770393
# phosphate__median                       15.770393
# glucose__length                         13.353474
# glucose__mean                           13.353474
# glucose__variance                       13.353474
# glucose__sum_values                     13.353474
# glucose__median                         13.353474
# glucose__standard_deviation             13.353474
# glucose__maximum                        13.353474
# glucose__root_mean_square               13.353474
# glucose__minimum                        13.353474
# calcium__sum_values                     11.238671
# calcium__median                         11.238671
# calcium__mean                           11.238671
# calcium__length                         11.238671
# calcium__standard_deviation             11.238671
# calcium__variance                       11.238671
# calcium__root_mean_square               11.238671
# calcium__maximum                        11.238671
# calcium__minimum                        11.238671
# chloride__root_mean_square               9.667674
# chloride__variance                       9.667674
# chloride__standard_deviation             9.667674
# chloride__length                         9.667674
# chloride__minimum                        9.667674
# chloride__sum_values                     9.667674
# chloride__median                         9.667674
# chloride__mean                           9.667674
# chloride__maximum                        9.667674
# alkphos__root_mean_square                8.177241
# alkphos__sum_values                      8.177241
# alkphos__median                          8.177241
# alkphos__mean                            8.177241
# alkphos__length                          8.177241
# alkphos__standard_deviation              8.177241
# alkphos__variance                        8.177241
# alkphos__minimum                         8.177241
# alkphos__maximum                         8.177241
# platelet__median                         7.673716
# platelet__standard_deviation             7.673716
# platelet__length                         7.673716
# platelet__variance                       7.673716
# platelet__root_mean_square               7.673716
# platelet__maximum                        7.673716
# platelet__minimum                        7.673716
# platelet__mean                           7.673716
# platelet__sum_values                     7.673716
# wcc__median                              7.593152
# wcc__variance                            7.593152
# wcc__root_mean_square                    7.593152
# wcc__standard_deviation                  7.593152
# wcc__length                              7.593152
# wcc__sum_values                          7.593152
# wcc__mean                                7.593152
# wcc__minimum                             7.593152
# wcc__maximum                             7.593152
# albumin__minimum                         7.411883
# albumin__sum_values                      7.411883
# albumin__maximum                         7.411883
# albumin__variance                        7.411883
# albumin__standard_deviation              7.411883
# albumin__length                          7.411883
# albumin__mean                            7.411883
# albumin__median                          7.411883
# albumin__root_mean_square                7.411883
# haemoglobin__standard_deviation          7.250755
# haemoglobin__minimum                     7.250755
# haemoglobin__maximum                     7.250755
# haemoglobin__root_mean_square            7.250755
# haemoglobin__variance                    7.250755
# haemoglobin__sum_values                  7.250755
# haemoglobin__length                      7.250755
# haemoglobin__mean                        7.250755
# haemoglobin__median                      7.250755
# sodium__length                           5.861027
# sodium__mean                             5.861027
# sodium__median                           5.861027
# sodium__variance                         5.861027
# sodium__standard_deviation               5.861027
# sodium__root_mean_square                 5.861027
# sodium__minimum                          5.861027
# sodium__sum_values                       5.861027
# sodium__maximum                          5.861027
# potassium__standard_deviation            5.760322
# potassium__mean                          5.760322
# potassium__root_mean_square              5.760322
# potassium__sum_values                    5.760322
# potassium__median                        5.760322
# potassium__variance                      5.760322
# potassium__length                        5.760322
# potassium__minimum                       5.760322
# potassium__maximum                       5.760322
# urea__maximum                            5.639476
# ureacreat_ratio__minimum                 5.639476
# ureacreat_ratio__maximum                 5.639476
# ureacreat_ratio__root_mean_square        5.639476
# ureacreat_ratio__variance                5.639476
# ureacreat_ratio__standard_deviation      5.639476
# ureacreat_ratio__length                  5.639476
# ureacreat_ratio__mean                    5.639476
# ureacreat_ratio__median                  5.639476
# ureacreat_ratio__sum_values              5.639476
# urea__minimum                            5.639476
# urea__root_mean_square                   5.639476
# urea__standard_deviation                 5.639476
# urea__length                             5.639476
# urea__mean                               5.639476
# urea__median                             5.639476
# urea__sum_values                         5.639476
# urea__variance                           5.639476
# egfr__standard_deviation                 3.182276
# egfr__variance                           3.182276
# egfr__root_mean_square                   3.182276
# egfr__maximum                            3.182276
# egfr__minimum                            3.182276
# egfr__length                             3.182276
# egfr__mean                               3.182276
# egfr__median                             3.182276
# egfr__sum_values                         3.182276
# creatinine__sum_values                   3.081571
# creatinine__median                       3.081571
# creatinine__minimum                      3.081571
# creatinine__maximum                      3.081571
# creatinine__root_mean_square             3.081571
# creatinine__variance                     3.081571
# creatinine__standard_deviation           3.081571
# creatinine__mean                         3.081571
# creatinine__length                       3.081571
# cat4.5                                   0.000000
# cat2.5                                   0.000000
# cat3                                     0.000000
# cat3.5                                   0.000000
# cat4                                     0.000000
# cat6                                     0.000000
# cat5                                     0.000000
# cat5.5                                   0.000000
# cat1.5                                   0.000000
# cat6.5                                   0.000000
# cat7                                     0.000000
# cat7.5                                   0.000000
# cat2                                     0.000000
# id                                       0.000000
# cat1                                     0.000000
# cat0.5                                   0.000000
# age.init                                 0.000000
# egfr.y                                   0.000000
# value_egfr_init                          0.000000
# gender                                   0.000000
# gn                                       0.000000
# dkd                                      0.000000
# htn                                      0.000000
# aki_3                                    0.000000
# aki_2                                    0.000000
# aki_1                                    0.000000
# cat8                                     0.000000

# %%
def to_category(df):
    cols = df.select_dtypes(include='object').columns
    for col in cols:
        df[col] = df[col].astype('category')
    return df

def drop_missing(df):
    threshold = len(df)*0.5
    df.dropna(axis=1, thresh=threshold, inplace=True)
    return df

def copy_df(df):
    return df.copy()

# %%
df_cleaned = (df.pipe(copy_df).pipe(drop_missing).pipe(to_category))
df_cleaned.shape
# Out:
# (4965, 396)

# %%
df_rm_intrain = df_cleaned.query("cat2 == 'non_eskd'")
df_rm_intrain.shape
# Out:
# (3708, 396)

# %%
df_rm_intrain.set_index('id', inplace=True)

# %%
df_rm_intrain['cat3'].value_counts()
# Out:
# non_eskd    3586
# eskd         122
# Name: cat3, dtype: int64

# %%
df_rm_intrain['cat4'].value_counts()
# Out:
# non_eskd    3484
# eskd         224
# Name: cat4, dtype: int64

# %%
df_rm_intrain['cat7'].value_counts()
# Out:
# non_eskd    3261
# eskd         447
# Name: cat7, dtype: int64

# %%
percent_missing = df_rm_intrain.isnull().sum()*100 / len(df_rm_intrain)
missing_df_rm_intrain = pd.DataFrame({'column_name': df_rm_intrain.columns, 'percent_miss': percent_missing})
missing_df_rm_intrain.sort_values(by='percent_miss', ascending=False)
# Out:
#                                                              column_name  \
# sta_dia__mean                                              sta_dia__mean
# sta_sys__mean                                              sta_sys__mean
# sta_dia__sum_values                                  sta_dia__sum_values
# sta_dia__median                                          sta_dia__median
# sta_sys__maximum                                        sta_sys__maximum
# sta_sys__root_mean_square                      sta_sys__root_mean_square
# sta_sys__variance                                      sta_sys__variance
# sta_sys__standard_deviation                  sta_sys__standard_deviation
# sta_sys__length                                          sta_sys__length
# sta_sys__minimum                                        sta_sys__minimum
# sta_sys__median                                          sta_sys__median
# sta_dia__minimum                                        sta_dia__minimum
# sta_dia__maximum                                        sta_dia__maximum
# sta_dia__root_mean_square                      sta_dia__root_mean_square
# sta_dia__variance                                      sta_dia__variance
# sta_dia__standard_deviation                  sta_dia__standard_deviation
# sta_dia__length                                          sta_dia__length
# sta_sys__sum_values                                  sta_sys__sum_values
# magnesium__median                                      magnesium__median
# magnesium__variance                                  magnesium__variance
# magnesium__root_mean_square                  magnesium__root_mean_square
# magnesium__maximum                                    magnesium__maximum
# magnesium__minimum                                    magnesium__minimum
# magnesium__mean                                          magnesium__mean
# magnesium__standard_deviation              magnesium__standard_deviation
# magnesium__sum_values                              magnesium__sum_values
# magnesium__length                                      magnesium__length
# sit_sys__variance                                      sit_sys__variance
# sit_sys__root_mean_square                      sit_sys__root_mean_square
# sit_sys__minimum                                        sit_sys__minimum
# sit_sys__median                                          sit_sys__median
# sit_sys__maximum                                        sit_sys__maximum
# sit_sys__sum_values                                  sit_sys__sum_values
# sit_sys__length                                          sit_sys__length
# sit_sys__mean                                              sit_sys__mean
# sit_dia__minimum                                        sit_dia__minimum
# sit_dia__maximum                                        sit_dia__maximum
# sit_dia__root_mean_square                      sit_dia__root_mean_square
# sit_dia__variance                                      sit_dia__variance
# sit_dia__standard_deviation                  sit_dia__standard_deviation
# sit_dia__length                                          sit_dia__length
# sit_dia__mean                                              sit_dia__mean
# sit_dia__median                                          sit_dia__median
# sit_dia__sum_values                                  sit_dia__sum_values
# sit_sys__standard_deviation                  sit_sys__standard_deviation
# rdw__root_mean_square                              rdw__root_mean_square
# rdw__minimum                                                rdw__minimum
# rdw__length                                                  rdw__length
# rdw__standard_deviation                          rdw__standard_deviation
# rdw__variance                                              rdw__variance
# rdw__maximum                                                rdw__maximum
# rdw__median                                                  rdw__median
# rdw__sum_values                                          rdw__sum_values
# rdw__mean                                                      rdw__mean
# weight__length                                            weight__length
# weight__median                                            weight__median
# weight__sum_values                                    weight__sum_values
# weight__standard_deviation                    weight__standard_deviation
# weight__variance                                        weight__variance
# weight__root_mean_square                        weight__root_mean_square
# weight__maximum                                          weight__maximum
# weight__minimum                                          weight__minimum
# weight__mean                                                weight__mean
# triglycerides__sum_values                      triglycerides__sum_values
# triglycerides__minimum                            triglycerides__minimum
# triglycerides__median                              triglycerides__median
# triglycerides__root_mean_square          triglycerides__root_mean_square
# triglycerides__variance                          triglycerides__variance
# triglycerides__standard_deviation      triglycerides__standard_deviation
# triglycerides__length                              triglycerides__length
# triglycerides__mean                                  triglycerides__mean
# triglycerides__maximum                            triglycerides__maximum
# cholesterol__minimum                                cholesterol__minimum
# cholesterol__maximum                                cholesterol__maximum
# cholesterol__mean                                      cholesterol__mean
# cholesterol__sum_values                          cholesterol__sum_values
# cholesterol__median                                  cholesterol__median
# cholesterol__root_mean_square              cholesterol__root_mean_square
# cholesterol__length                                  cholesterol__length
# cholesterol__standard_deviation          cholesterol__standard_deviation
# cholesterol__variance                              cholesterol__variance
# globulin__minimum                                      globulin__minimum
# globulin__root_mean_square                    globulin__root_mean_square
# globulin__variance                                    globulin__variance
# globulin__standard_deviation                globulin__standard_deviation
# globulin__length                                        globulin__length
# globulin__mean                                            globulin__mean
# globulin__median                                        globulin__median
# globulin__sum_values                                globulin__sum_values
# globulin__maximum                                      globulin__maximum
# protein__median                                          protein__median
# protein__root_mean_square                      protein__root_mean_square
# protein__mean                                              protein__mean
# protein__length                                          protein__length
# protein__standard_deviation                  protein__standard_deviation
# protein__variance                                      protein__variance
# protein__sum_values                                  protein__sum_values
# protein__maximum                                        protein__maximum
# protein__minimum                                        protein__minimum
# bicarbonate__standard_deviation          bicarbonate__standard_deviation
# bicarbonate__variance                              bicarbonate__variance
# bicarbonate__root_mean_square              bicarbonate__root_mean_square
# bicarbonate__maximum                                bicarbonate__maximum
# bicarbonate__length                                  bicarbonate__length
# bicarbonate__median                                  bicarbonate__median
# bicarbonate__sum_values                          bicarbonate__sum_values
# bicarbonate__mean                                      bicarbonate__mean
# bicarbonate__minimum                                bicarbonate__minimum
# ggt__median                                                  ggt__median
# ggt__minimum                                                ggt__minimum
# ggt__root_mean_square                              ggt__root_mean_square
# ggt__variance                                              ggt__variance
# ggt__standard_deviation                          ggt__standard_deviation
# ggt__length                                                  ggt__length
# ggt__mean                                                      ggt__mean
# ggt__sum_values                                          ggt__sum_values
# ggt__maximum                                                ggt__maximum
# bilirubin__minimum                                    bilirubin__minimum
# bilirubin__root_mean_square                  bilirubin__root_mean_square
# bilirubin__variance                                  bilirubin__variance
# bilirubin__length                                      bilirubin__length
# bilirubin__mean                                          bilirubin__mean
# bilirubin__median                                      bilirubin__median
# bilirubin__sum_values                              bilirubin__sum_values
# bilirubin__maximum                                    bilirubin__maximum
# bilirubin__standard_deviation              bilirubin__standard_deviation
# alt__maximum                                                alt__maximum
# alt__root_mean_square                              alt__root_mean_square
# alt__variance                                              alt__variance
# alt__standard_deviation                          alt__standard_deviation
# alt__length                                                  alt__length
# alt__mean                                                      alt__mean
# alt__median                                                  alt__median
# alt__sum_values                                          alt__sum_values
# alt__minimum                                                alt__minimum
# basophils__variance                                  basophils__variance
# basophils__minimum                                    basophils__minimum
# basophils__maximum                                    basophils__maximum
# basophils__root_mean_square                  basophils__root_mean_square
# basophils__mean                                          basophils__mean
# basophils__standard_deviation              basophils__standard_deviation
# basophils__length                                      basophils__length
# basophils__median                                      basophils__median
# basophils__sum_values                              basophils__sum_values
# eosinophils__standard_deviation          eosinophils__standard_deviation
# eosinophils__sum_values                          eosinophils__sum_values
# eosinophils__mean                                      eosinophils__mean
# eosinophils__length                                  eosinophils__length
# eosinophils__median                                  eosinophils__median
# eosinophils__variance                              eosinophils__variance
# eosinophils__maximum                                eosinophils__maximum
# eosinophils__minimum                                eosinophils__minimum
# eosinophils__root_mean_square              eosinophils__root_mean_square
# monocytes__standard_deviation              monocytes__standard_deviation
# lymphocytes__maximum                                lymphocytes__maximum
# lymphocytes__root_mean_square              lymphocytes__root_mean_square
# lymphocytes__variance                              lymphocytes__variance
# lymphocytes__standard_deviation          lymphocytes__standard_deviation
# lymphocytes__length                                  lymphocytes__length
# lymphocytes__mean                                      lymphocytes__mean
# lymphocytes__median                                  lymphocytes__median
# lymphocytes__sum_values                          lymphocytes__sum_values
# monocytes__median                                      monocytes__median
# monocytes__mean                                          monocytes__mean
# monocytes__length                                      monocytes__length
# monocytes__root_mean_square                  monocytes__root_mean_square
# monocytes__variance                                  monocytes__variance
# monocytes__maximum                                    monocytes__maximum
# monocytes__minimum                                    monocytes__minimum
# neutrophils__maximum                                neutrophils__maximum
# neutrophils__root_mean_square              neutrophils__root_mean_square
# neutrophils__variance                              neutrophils__variance
# neutrophils__standard_deviation          neutrophils__standard_deviation
# neutrophils__length                                  neutrophils__length
# neutrophils__mean                                      neutrophils__mean
# neutrophils__median                                  neutrophils__median
# neutrophils__sum_values                          neutrophils__sum_values
# lymphocytes__minimum                                lymphocytes__minimum
# monocytes__sum_values                              monocytes__sum_values
# neutrophils__minimum                                neutrophils__minimum
# mch__variance                                              mch__variance
# rbc__mean                                                      rbc__mean
# mch__minimum                                                mch__minimum
# mch__maximum                                                mch__maximum
# mch__root_mean_square                              mch__root_mean_square
# mch__standard_deviation                          mch__standard_deviation
# mch__length                                                  mch__length
# mch__mean                                                      mch__mean
# mch__median                                                  mch__median
# mch__sum_values                                          mch__sum_values
# rbc__minimum                                                rbc__minimum
# rbc__maximum                                                rbc__maximum
# rbc__root_mean_square                              rbc__root_mean_square
# rbc__variance                                              rbc__variance
# rbc__standard_deviation                          rbc__standard_deviation
# rbc__length                                                  rbc__length
# rbc__sum_values                                          rbc__sum_values
# mchc__sum_values                                        mchc__sum_values
# mchc__median                                                mchc__median
# mchc__mean                                                    mchc__mean
# mchc__length                                                mchc__length
# mcv__minimum                                                mcv__minimum
# mcv__maximum                                                mcv__maximum
# mcv__root_mean_square                              mcv__root_mean_square
# mcv__variance                                              mcv__variance
# mcv__standard_deviation                          mcv__standard_deviation
# mcv__length                                                  mcv__length
# mcv__mean                                                      mcv__mean
# mcv__median                                                  mcv__median
# mcv__sum_values                                          mcv__sum_values
# mchc__minimum                                              mchc__minimum
# mchc__maximum                                              mchc__maximum
# mchc__root_mean_square                            mchc__root_mean_square
# mchc__variance                                            mchc__variance
# mchc__standard_deviation                        mchc__standard_deviation
# rbc__median                                                  rbc__median
# haematocrit__mean                                      haematocrit__mean
# haematocrit__standard_deviation          haematocrit__standard_deviation
# haematocrit__length                                  haematocrit__length
# haematocrit__variance                              haematocrit__variance
# haematocrit__root_mean_square              haematocrit__root_mean_square
# haematocrit__maximum                                haematocrit__maximum
# haematocrit__minimum                                haematocrit__minimum
# haematocrit__sum_values                          haematocrit__sum_values
# haematocrit__median                                  haematocrit__median
# caphos_product__median                            caphos_product__median
# caphos_product__sum_values                    caphos_product__sum_values
# caphos_product__minimum                          caphos_product__minimum
# caphos_product__length                            caphos_product__length
# caphos_product__standard_deviation    caphos_product__standard_deviation
# caphos_product__variance                        caphos_product__variance
# caphos_product__root_mean_square        caphos_product__root_mean_square
# caphos_product__maximum                          caphos_product__maximum
# caphos_product__mean                                caphos_product__mean
# phosphate__minimum                                    phosphate__minimum
# phosphate__root_mean_square                  phosphate__root_mean_square
# phosphate__variance                                  phosphate__variance
# phosphate__maximum                                    phosphate__maximum
# phosphate__sum_values                              phosphate__sum_values
# phosphate__median                                      phosphate__median
# phosphate__mean                                          phosphate__mean
# phosphate__length                                      phosphate__length
# phosphate__standard_deviation              phosphate__standard_deviation
# glucose__length                                          glucose__length
# glucose__maximum                                        glucose__maximum
# glucose__root_mean_square                      glucose__root_mean_square
# glucose__variance                                      glucose__variance
# glucose__standard_deviation                  glucose__standard_deviation
# glucose__minimum                                        glucose__minimum
# glucose__median                                          glucose__median
# glucose__sum_values                                  glucose__sum_values
# glucose__mean                                              glucose__mean
# calcium__maximum                                        calcium__maximum
# calcium__variance                                      calcium__variance
# calcium__standard_deviation                  calcium__standard_deviation
# calcium__length                                          calcium__length
# calcium__mean                                              calcium__mean
# calcium__median                                          calcium__median
# calcium__sum_values                                  calcium__sum_values
# calcium__minimum                                        calcium__minimum
# calcium__root_mean_square                      calcium__root_mean_square
# chloride__maximum                                      chloride__maximum
# chloride__variance                                    chloride__variance
# chloride__standard_deviation                chloride__standard_deviation
# chloride__length                                        chloride__length
# chloride__mean                                            chloride__mean
# chloride__median                                        chloride__median
# chloride__minimum                                      chloride__minimum
# chloride__sum_values                                chloride__sum_values
# chloride__root_mean_square                    chloride__root_mean_square
# alkphos__root_mean_square                      alkphos__root_mean_square
# alkphos__variance                                      alkphos__variance
# alkphos__minimum                                        alkphos__minimum
# alkphos__maximum                                        alkphos__maximum
# alkphos__sum_values                                  alkphos__sum_values
# alkphos__median                                          alkphos__median
# alkphos__mean                                              alkphos__mean
# alkphos__length                                          alkphos__length
# alkphos__standard_deviation                  alkphos__standard_deviation
# platelet__sum_values                                platelet__sum_values
# platelet__median                                        platelet__median
# platelet__mean                                            platelet__mean
# platelet__standard_deviation                platelet__standard_deviation
# platelet__variance                                    platelet__variance
# platelet__root_mean_square                    platelet__root_mean_square
# platelet__length                                        platelet__length
# platelet__minimum                                      platelet__minimum
# platelet__maximum                                      platelet__maximum
# wcc__maximum                                                wcc__maximum
# wcc__root_mean_square                              wcc__root_mean_square
# wcc__variance                                              wcc__variance
# wcc__standard_deviation                          wcc__standard_deviation
# wcc__length                                                  wcc__length
# wcc__mean                                                      wcc__mean
# wcc__median                                                  wcc__median
# wcc__sum_values                                          wcc__sum_values
# wcc__minimum                                                wcc__minimum
# albumin__sum_values                                  albumin__sum_values
# albumin__median                                          albumin__median
# albumin__mean                                              albumin__mean
# albumin__maximum                                        albumin__maximum
# albumin__root_mean_square                      albumin__root_mean_square
# albumin__variance                                      albumin__variance
# albumin__standard_deviation                  albumin__standard_deviation
# albumin__length                                          albumin__length
# albumin__minimum                                        albumin__minimum
# haemoglobin__sum_values                          haemoglobin__sum_values
# haemoglobin__median                                  haemoglobin__median
# haemoglobin__mean                                      haemoglobin__mean
# haemoglobin__length                                  haemoglobin__length
# haemoglobin__standard_deviation          haemoglobin__standard_deviation
# haemoglobin__variance                              haemoglobin__variance
# haemoglobin__root_mean_square              haemoglobin__root_mean_square
# haemoglobin__maximum                                haemoglobin__maximum
# haemoglobin__minimum                                haemoglobin__minimum
# sodium__sum_values                                    sodium__sum_values
# sodium__standard_deviation                    sodium__standard_deviation
# sodium__median                                            sodium__median
# sodium__mean                                                sodium__mean
# sodium__length                                            sodium__length
# sodium__minimum                                          sodium__minimum
# sodium__variance                                        sodium__variance
# sodium__root_mean_square                        sodium__root_mean_square
# sodium__maximum                                          sodium__maximum
# potassium__standard_deviation              potassium__standard_deviation
# potassium__sum_values                              potassium__sum_values
# potassium__median                                      potassium__median
# potassium__mean                                          potassium__mean
# potassium__length                                      potassium__length
# potassium__variance                                  potassium__variance
# potassium__maximum                                    potassium__maximum
# potassium__minimum                                    potassium__minimum
# potassium__root_mean_square                  potassium__root_mean_square
# ureacreat_ratio__sum_values                  ureacreat_ratio__sum_values
# urea__minimum                                              urea__minimum
# ureacreat_ratio__maximum                        ureacreat_ratio__maximum
# ureacreat_ratio__root_mean_square      ureacreat_ratio__root_mean_square
# ureacreat_ratio__variance                      ureacreat_ratio__variance
# ureacreat_ratio__standard_deviation  ureacreat_ratio__standard_deviation
# ureacreat_ratio__minimum                        ureacreat_ratio__minimum
# ureacreat_ratio__length                          ureacreat_ratio__length
# ureacreat_ratio__mean                              ureacreat_ratio__mean
# urea__root_mean_square                            urea__root_mean_square
# urea__maximum                                              urea__maximum
# urea__variance                                            urea__variance
# urea__standard_deviation                        urea__standard_deviation
# urea__length                                                urea__length
# urea__mean                                                    urea__mean
# urea__median                                                urea__median
# urea__sum_values                                        urea__sum_values
# ureacreat_ratio__median                          ureacreat_ratio__median
# egfr__sum_values                                        egfr__sum_values
# egfr__root_mean_square                            egfr__root_mean_square
# egfr__maximum                                              egfr__maximum
# egfr__median                                                egfr__median
# egfr__minimum                                              egfr__minimum
# egfr__variance                                            egfr__variance
# egfr__standard_deviation                        egfr__standard_deviation
# egfr__length                                                egfr__length
# egfr__mean                                                    egfr__mean
# creatinine__maximum                                  creatinine__maximum
# creatinine__minimum                                  creatinine__minimum
# creatinine__sum_values                            creatinine__sum_values
# creatinine__root_mean_square                creatinine__root_mean_square
# creatinine__mean                                        creatinine__mean
# creatinine__length                                    creatinine__length
# creatinine__standard_deviation            creatinine__standard_deviation
# creatinine__variance                                creatinine__variance
# creatinine__median                                    creatinine__median
# cat3                                                                cat3
# cat3.5                                                            cat3.5
# cat4                                                                cat4
# cat4.5                                                            cat4.5
# cat5                                                                cat5
# cat6.5                                                            cat6.5
# cat5.5                                                            cat5.5
# cat6                                                                cat6
# cat7                                                                cat7
# cat7.5                                                            cat7.5
# cat2                                                                cat2
# cat2.5                                                            cat2.5
# gn                                                                    gn
# cat1.5                                                            cat1.5
# cat1                                                                cat1
# cat0.5                                                            cat0.5
# age.init                                                        age.init
# egfr.y                                                            egfr.y
# value_egfr_init                                          value_egfr_init
# gender                                                            gender
# dkd                                                                  dkd
# htn                                                                  htn
# aki_3                                                              aki_3
# aki_2                                                              aki_2
# aki_1                                                              aki_1
# cat8                                                                cat8
#
#                                      percent_miss
# sta_dia__mean                           46.413161
# sta_sys__mean                           46.413161
# sta_dia__sum_values                     46.413161
# sta_dia__median                         46.413161
# sta_sys__maximum                        46.413161
# sta_sys__root_mean_square               46.413161
# sta_sys__variance                       46.413161
# sta_sys__standard_deviation             46.413161
# sta_sys__length                         46.413161
# sta_sys__minimum                        46.413161
# sta_sys__median                         46.413161
# sta_dia__minimum                        46.413161
# sta_dia__maximum                        46.413161
# sta_dia__root_mean_square               46.413161
# sta_dia__variance                       46.413161
# sta_dia__standard_deviation             46.413161
# sta_dia__length                         46.413161
# sta_sys__sum_values                     46.413161
# magnesium__median                       45.550162
# magnesium__variance                     45.550162
# magnesium__root_mean_square             45.550162
# magnesium__maximum                      45.550162
# magnesium__minimum                      45.550162
# magnesium__mean                         45.550162
# magnesium__standard_deviation           45.550162
# magnesium__sum_values                   45.550162
# magnesium__length                       45.550162
# sit_sys__variance                       45.280475
# sit_sys__root_mean_square               45.280475
# sit_sys__minimum                        45.280475
# sit_sys__median                         45.280475
# sit_sys__maximum                        45.280475
# sit_sys__sum_values                     45.280475
# sit_sys__length                         45.280475
# sit_sys__mean                           45.280475
# sit_dia__minimum                        45.280475
# sit_dia__maximum                        45.280475
# sit_dia__root_mean_square               45.280475
# sit_dia__variance                       45.280475
# sit_dia__standard_deviation             45.280475
# sit_dia__length                         45.280475
# sit_dia__mean                           45.280475
# sit_dia__median                         45.280475
# sit_dia__sum_values                     45.280475
# sit_sys__standard_deviation             45.280475
# rdw__root_mean_square                   44.660194
# rdw__minimum                            44.660194
# rdw__length                             44.660194
# rdw__standard_deviation                 44.660194
# rdw__variance                           44.660194
# rdw__maximum                            44.660194
# rdw__median                             44.660194
# rdw__sum_values                         44.660194
# rdw__mean                               44.660194
# weight__length                          44.579288
# weight__median                          44.579288
# weight__sum_values                      44.579288
# weight__standard_deviation              44.579288
# weight__variance                        44.579288
# weight__root_mean_square                44.579288
# weight__maximum                         44.579288
# weight__minimum                         44.579288
# weight__mean                            44.579288
# triglycerides__sum_values               40.480043
# triglycerides__minimum                  40.480043
# triglycerides__median                   40.480043
# triglycerides__root_mean_square         40.480043
# triglycerides__variance                 40.480043
# triglycerides__standard_deviation       40.480043
# triglycerides__length                   40.480043
# triglycerides__mean                     40.480043
# triglycerides__maximum                  40.480043
# cholesterol__minimum                    40.237325
# cholesterol__maximum                    40.237325
# cholesterol__mean                       40.237325
# cholesterol__sum_values                 40.237325
# cholesterol__median                     40.237325
# cholesterol__root_mean_square           40.237325
# cholesterol__length                     40.237325
# cholesterol__standard_deviation         40.237325
# cholesterol__variance                   40.237325
# globulin__minimum                       36.111111
# globulin__root_mean_square              36.111111
# globulin__variance                      36.111111
# globulin__standard_deviation            36.111111
# globulin__length                        36.111111
# globulin__mean                          36.111111
# globulin__median                        36.111111
# globulin__sum_values                    36.111111
# globulin__maximum                       36.111111
# protein__median                         36.057174
# protein__root_mean_square               36.057174
# protein__mean                           36.057174
# protein__length                         36.057174
# protein__standard_deviation             36.057174
# protein__variance                       36.057174
# protein__sum_values                     36.057174
# protein__maximum                        36.057174
# protein__minimum                        36.057174
# bicarbonate__standard_deviation         34.492988
# bicarbonate__variance                   34.492988
# bicarbonate__root_mean_square           34.492988
# bicarbonate__maximum                    34.492988
# bicarbonate__length                     34.492988
# bicarbonate__median                     34.492988
# bicarbonate__sum_values                 34.492988
# bicarbonate__mean                       34.492988
# bicarbonate__minimum                    34.492988
# ggt__median                             34.331176
# ggt__minimum                            34.331176
# ggt__root_mean_square                   34.331176
# ggt__variance                           34.331176
# ggt__standard_deviation                 34.331176
# ggt__length                             34.331176
# ggt__mean                               34.331176
# ggt__sum_values                         34.331176
# ggt__maximum                            34.331176
# bilirubin__minimum                      34.304207
# bilirubin__root_mean_square             34.304207
# bilirubin__variance                     34.304207
# bilirubin__length                       34.304207
# bilirubin__mean                         34.304207
# bilirubin__median                       34.304207
# bilirubin__sum_values                   34.304207
# bilirubin__maximum                      34.304207
# bilirubin__standard_deviation           34.304207
# alt__maximum                            34.277238
# alt__root_mean_square                   34.277238
# alt__variance                           34.277238
# alt__standard_deviation                 34.277238
# alt__length                             34.277238
# alt__mean                               34.277238
# alt__median                             34.277238
# alt__sum_values                         34.277238
# alt__minimum                            34.277238
# basophils__variance                     31.903991
# basophils__minimum                      31.903991
# basophils__maximum                      31.903991
# basophils__root_mean_square             31.903991
# basophils__mean                         31.903991
# basophils__standard_deviation           31.903991
# basophils__length                       31.903991
# basophils__median                       31.903991
# basophils__sum_values                   31.903991
# eosinophils__standard_deviation         31.796117
# eosinophils__sum_values                 31.796117
# eosinophils__mean                       31.796117
# eosinophils__length                     31.796117
# eosinophils__median                     31.796117
# eosinophils__variance                   31.796117
# eosinophils__maximum                    31.796117
# eosinophils__minimum                    31.796117
# eosinophils__root_mean_square           31.796117
# monocytes__standard_deviation           31.256742
# lymphocytes__maximum                    31.256742
# lymphocytes__root_mean_square           31.256742
# lymphocytes__variance                   31.256742
# lymphocytes__standard_deviation         31.256742
# lymphocytes__length                     31.256742
# lymphocytes__mean                       31.256742
# lymphocytes__median                     31.256742
# lymphocytes__sum_values                 31.256742
# monocytes__median                       31.256742
# monocytes__mean                         31.256742
# monocytes__length                       31.256742
# monocytes__root_mean_square             31.256742
# monocytes__variance                     31.256742
# monocytes__maximum                      31.256742
# monocytes__minimum                      31.256742
# neutrophils__maximum                    31.256742
# neutrophils__root_mean_square           31.256742
# neutrophils__variance                   31.256742
# neutrophils__standard_deviation         31.256742
# neutrophils__length                     31.256742
# neutrophils__mean                       31.256742
# neutrophils__median                     31.256742
# neutrophils__sum_values                 31.256742
# lymphocytes__minimum                    31.256742
# monocytes__sum_values                   31.256742
# neutrophils__minimum                    31.256742
# mch__variance                           31.229773
# rbc__mean                               31.229773
# mch__minimum                            31.229773
# mch__maximum                            31.229773
# mch__root_mean_square                   31.229773
# mch__standard_deviation                 31.229773
# mch__length                             31.229773
# mch__mean                               31.229773
# mch__median                             31.229773
# mch__sum_values                         31.229773
# rbc__minimum                            31.229773
# rbc__maximum                            31.229773
# rbc__root_mean_square                   31.229773
# rbc__variance                           31.229773
# rbc__standard_deviation                 31.229773
# rbc__length                             31.229773
# rbc__sum_values                         31.229773
# mchc__sum_values                        31.229773
# mchc__median                            31.229773
# mchc__mean                              31.229773
# mchc__length                            31.229773
# mcv__minimum                            31.229773
# mcv__maximum                            31.229773
# mcv__root_mean_square                   31.229773
# mcv__variance                           31.229773
# mcv__standard_deviation                 31.229773
# mcv__length                             31.229773
# mcv__mean                               31.229773
# mcv__median                             31.229773
# mcv__sum_values                         31.229773
# mchc__minimum                           31.229773
# mchc__maximum                           31.229773
# mchc__root_mean_square                  31.229773
# mchc__variance                          31.229773
# mchc__standard_deviation                31.229773
# rbc__median                             31.229773
# haematocrit__mean                       31.202805
# haematocrit__standard_deviation         31.202805
# haematocrit__length                     31.202805
# haematocrit__variance                   31.202805
# haematocrit__root_mean_square           31.202805
# haematocrit__maximum                    31.202805
# haematocrit__minimum                    31.202805
# haematocrit__sum_values                 31.202805
# haematocrit__median                     31.202805
# caphos_product__median                  20.145631
# caphos_product__sum_values              20.145631
# caphos_product__minimum                 20.145631
# caphos_product__length                  20.145631
# caphos_product__standard_deviation      20.145631
# caphos_product__variance                20.145631
# caphos_product__root_mean_square        20.145631
# caphos_product__maximum                 20.145631
# caphos_product__mean                    20.145631
# phosphate__minimum                      20.091694
# phosphate__root_mean_square             20.091694
# phosphate__variance                     20.091694
# phosphate__maximum                      20.091694
# phosphate__sum_values                   20.091694
# phosphate__median                       20.091694
# phosphate__mean                         20.091694
# phosphate__length                       20.091694
# phosphate__standard_deviation           20.091694
# glucose__length                         16.558792
# glucose__maximum                        16.558792
# glucose__root_mean_square               16.558792
# glucose__variance                       16.558792
# glucose__standard_deviation             16.558792
# glucose__minimum                        16.558792
# glucose__median                         16.558792
# glucose__sum_values                     16.558792
# glucose__mean                           16.558792
# calcium__maximum                        14.050701
# calcium__variance                       14.050701
# calcium__standard_deviation             14.050701
# calcium__length                         14.050701
# calcium__mean                           14.050701
# calcium__median                         14.050701
# calcium__sum_values                     14.050701
# calcium__minimum                        14.050701
# calcium__root_mean_square               14.050701
# chloride__maximum                       12.028047
# chloride__variance                      12.028047
# chloride__standard_deviation            12.028047
# chloride__length                        12.028047
# chloride__mean                          12.028047
# chloride__median                        12.028047
# chloride__minimum                       12.028047
# chloride__sum_values                    12.028047
# chloride__root_mean_square              12.028047
# alkphos__root_mean_square                9.897519
# alkphos__variance                        9.897519
# alkphos__minimum                         9.897519
# alkphos__maximum                         9.897519
# alkphos__sum_values                      9.897519
# alkphos__median                          9.897519
# alkphos__mean                            9.897519
# alkphos__length                          9.897519
# alkphos__standard_deviation              9.897519
# platelet__sum_values                     9.304207
# platelet__median                         9.304207
# platelet__mean                           9.304207
# platelet__standard_deviation             9.304207
# platelet__variance                       9.304207
# platelet__root_mean_square               9.304207
# platelet__length                         9.304207
# platelet__minimum                        9.304207
# platelet__maximum                        9.304207
# wcc__maximum                             9.223301
# wcc__root_mean_square                    9.223301
# wcc__variance                            9.223301
# wcc__standard_deviation                  9.223301
# wcc__length                              9.223301
# wcc__mean                                9.223301
# wcc__median                              9.223301
# wcc__sum_values                          9.223301
# wcc__minimum                             9.223301
# albumin__sum_values                      8.926645
# albumin__median                          8.926645
# albumin__mean                            8.926645
# albumin__maximum                         8.926645
# albumin__root_mean_square                8.926645
# albumin__variance                        8.926645
# albumin__standard_deviation              8.926645
# albumin__length                          8.926645
# albumin__minimum                         8.926645
# haemoglobin__sum_values                  8.899676
# haemoglobin__median                      8.899676
# haemoglobin__mean                        8.899676
# haemoglobin__length                      8.899676
# haemoglobin__standard_deviation          8.899676
# haemoglobin__variance                    8.899676
# haemoglobin__root_mean_square            8.899676
# haemoglobin__maximum                     8.899676
# haemoglobin__minimum                     8.899676
# sodium__sum_values                       7.011866
# sodium__standard_deviation               7.011866
# sodium__median                           7.011866
# sodium__mean                             7.011866
# sodium__length                           7.011866
# sodium__minimum                          7.011866
# sodium__variance                         7.011866
# sodium__root_mean_square                 7.011866
# sodium__maximum                          7.011866
# potassium__standard_deviation            6.930960
# potassium__sum_values                    6.930960
# potassium__median                        6.930960
# potassium__mean                          6.930960
# potassium__length                        6.930960
# potassium__variance                      6.930960
# potassium__maximum                       6.930960
# potassium__minimum                       6.930960
# potassium__root_mean_square              6.930960
# ureacreat_ratio__sum_values              6.769148
# urea__minimum                            6.769148
# ureacreat_ratio__maximum                 6.769148
# ureacreat_ratio__root_mean_square        6.769148
# ureacreat_ratio__variance                6.769148
# ureacreat_ratio__standard_deviation      6.769148
# ureacreat_ratio__minimum                 6.769148
# ureacreat_ratio__length                  6.769148
# ureacreat_ratio__mean                    6.769148
# urea__root_mean_square                   6.769148
# urea__maximum                            6.769148
# urea__variance                           6.769148
# urea__standard_deviation                 6.769148
# urea__length                             6.769148
# urea__mean                               6.769148
# urea__median                             6.769148
# urea__sum_values                         6.769148
# ureacreat_ratio__median                  6.769148
# egfr__sum_values                         4.234088
# egfr__root_mean_square                   4.234088
# egfr__maximum                            4.234088
# egfr__median                             4.234088
# egfr__minimum                            4.234088
# egfr__variance                           4.234088
# egfr__standard_deviation                 4.234088
# egfr__length                             4.234088
# egfr__mean                               4.234088
# creatinine__maximum                      4.099245
# creatinine__minimum                      4.099245
# creatinine__sum_values                   4.099245
# creatinine__root_mean_square             4.099245
# creatinine__mean                         4.099245
# creatinine__length                       4.099245
# creatinine__standard_deviation           4.099245
# creatinine__variance                     4.099245
# creatinine__median                       4.099245
# cat3                                     0.000000
# cat3.5                                   0.000000
# cat4                                     0.000000
# cat4.5                                   0.000000
# cat5                                     0.000000
# cat6.5                                   0.000000
# cat5.5                                   0.000000
# cat6                                     0.000000
# cat7                                     0.000000
# cat7.5                                   0.000000
# cat2                                     0.000000
# cat2.5                                   0.000000
# gn                                       0.000000
# cat1.5                                   0.000000
# cat1                                     0.000000
# cat0.5                                   0.000000
# age.init                                 0.000000
# egfr.y                                   0.000000
# value_egfr_init                          0.000000
# gender                                   0.000000
# dkd                                      0.000000
# htn                                      0.000000
# aki_3                                    0.000000
# aki_2                                    0.000000
# aki_1                                    0.000000
# cat8                                     0.000000

# %%
dropped_cols = list(df_rm_intrain.columns[-18:])
dropped_cols.remove('age.init')
dropped_cols
# Out:
# ['egfr.y',
#  'cat0.5',
#  'cat1',
#  'cat1.5',
#  'cat2',
#  'cat2.5',
#  'cat3',
#  'cat3.5',
#  'cat4',
#  'cat4.5',
#  'cat5',
#  'cat5.5',
#  'cat6',
#  'cat6.5',
#  'cat7',
#  'cat7.5',
#  'cat8']

# %%
X = df_rm_intrain.drop(dropped_cols,axis=1).copy()
y = df_rm_intrain['cat7']
X.shape, y.shape
# Out:
# ((3708, 378), (3708,))

# %%
X['aki_3'] = X['aki_3'].astype('float')

# %%
pd.set_option('display.max_info_columns', 600)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3708 entries, 3916 to 23864
# Data columns (total 378 columns):
#  #    Column                               Dtype
# ---   ------                               -----
#  0    albumin__sum_values                  float64
#  1    albumin__median                      float64
#  2    albumin__mean                        float64
#  3    albumin__length                      float64
#  4    albumin__standard_deviation          float64
#  5    albumin__variance                    float64
#  6    albumin__root_mean_square            float64
#  7    albumin__maximum                     float64
#  8    albumin__minimum                     float64
#  9    alkphos__sum_values                  float64
#  10   alkphos__median                      float64
#  11   alkphos__mean                        float64
#  12   alkphos__length                      float64
#  13   alkphos__standard_deviation          float64
#  14   alkphos__variance                    float64
#  15   alkphos__root_mean_square            float64
#  16   alkphos__maximum                     float64
#  17   alkphos__minimum                     float64
#  18   calcium__sum_values                  float64
#  19   calcium__median                      float64
#  20   calcium__mean                        float64
#  21   calcium__length                      float64
#  22   calcium__standard_deviation          float64
#  23   calcium__variance                    float64
#  24   calcium__root_mean_square            float64
#  25   calcium__maximum                     float64
#  26   calcium__minimum                     float64
#  27   caphos_product__sum_values           float64
#  28   caphos_product__median               float64
#  29   caphos_product__mean                 float64
#  30   caphos_product__length               float64
#  31   caphos_product__standard_deviation   float64
#  32   caphos_product__variance             float64
#  33   caphos_product__root_mean_square     float64
#  34   caphos_product__maximum              float64
#  35   caphos_product__minimum              float64
#  36   chloride__sum_values                 float64
#  37   chloride__median                     float64
#  38   chloride__mean                       float64
#  39   chloride__length                     float64
#  40   chloride__standard_deviation         float64
#  41   chloride__variance                   float64
#  42   chloride__root_mean_square           float64
#  43   chloride__maximum                    float64
#  44   chloride__minimum                    float64
#  45   cholesterol__sum_values              float64
#  46   cholesterol__median                  float64
#  47   cholesterol__mean                    float64
#  48   cholesterol__length                  float64
#  49   cholesterol__standard_deviation      float64
#  50   cholesterol__variance                float64
#  51   cholesterol__root_mean_square        float64
#  52   cholesterol__maximum                 float64
#  53   cholesterol__minimum                 float64
#  54   creatinine__sum_values               float64
#  55   creatinine__median                   float64
#  56   creatinine__mean                     float64
#  57   creatinine__length                   float64
#  58   creatinine__standard_deviation       float64
#  59   creatinine__variance                 float64
#  60   creatinine__root_mean_square         float64
#  61   creatinine__maximum                  float64
#  62   creatinine__minimum                  float64
#  63   egfr__sum_values                     float64
#  64   egfr__median                         float64
#  65   egfr__mean                           float64
#  66   egfr__length                         float64
#  67   egfr__standard_deviation             float64
#  68   egfr__variance                       float64
#  69   egfr__root_mean_square               float64
#  70   egfr__maximum                        float64
#  71   egfr__minimum                        float64
#  72   glucose__sum_values                  float64
#  73   glucose__median                      float64
#  74   glucose__mean                        float64
#  75   glucose__length                      float64
#  76   glucose__standard_deviation          float64
#  77   glucose__variance                    float64
#  78   glucose__root_mean_square            float64
#  79   glucose__maximum                     float64
#  80   glucose__minimum                     float64
#  81   haemoglobin__sum_values              float64
#  82   haemoglobin__median                  float64
#  83   haemoglobin__mean                    float64
#  84   haemoglobin__length                  float64
#  85   haemoglobin__standard_deviation      float64
#  86   haemoglobin__variance                float64
#  87   haemoglobin__root_mean_square        float64
#  88   haemoglobin__maximum                 float64
#  89   haemoglobin__minimum                 float64
#  90   phosphate__sum_values                float64
#  91   phosphate__median                    float64
#  92   phosphate__mean                      float64
#  93   phosphate__length                    float64
#  94   phosphate__standard_deviation        float64
#  95   phosphate__variance                  float64
#  96   phosphate__root_mean_square          float64
#  97   phosphate__maximum                   float64
#  98   phosphate__minimum                   float64
#  99   platelet__sum_values                 float64
#  100  platelet__median                     float64
#  101  platelet__mean                       float64
#  102  platelet__length                     float64
#  103  platelet__standard_deviation         float64
#  104  platelet__variance                   float64
#  105  platelet__root_mean_square           float64
#  106  platelet__maximum                    float64
#  107  platelet__minimum                    float64
#  108  potassium__sum_values                float64
#  109  potassium__median                    float64
#  110  potassium__mean                      float64
#  111  potassium__length                    float64
#  112  potassium__standard_deviation        float64
#  113  potassium__variance                  float64
#  114  potassium__root_mean_square          float64
#  115  potassium__maximum                   float64
#  116  potassium__minimum                   float64
#  117  sodium__sum_values                   float64
#  118  sodium__median                       float64
#  119  sodium__mean                         float64
#  120  sodium__length                       float64
#  121  sodium__standard_deviation           float64
#  122  sodium__variance                     float64
#  123  sodium__root_mean_square             float64
#  124  sodium__maximum                      float64
#  125  sodium__minimum                      float64
#  126  triglycerides__sum_values            float64
#  127  triglycerides__median                float64
#  128  triglycerides__mean                  float64
#  129  triglycerides__length                float64
#  130  triglycerides__standard_deviation    float64
#  131  triglycerides__variance              float64
#  132  triglycerides__root_mean_square      float64
#  133  triglycerides__maximum               float64
#  134  triglycerides__minimum               float64
#  135  urea__sum_values                     float64
#  136  urea__median                         float64
#  137  urea__mean                           float64
#  138  urea__length                         float64
#  139  urea__standard_deviation             float64
#  140  urea__variance                       float64
#  141  urea__root_mean_square               float64
#  142  urea__maximum                        float64
#  143  urea__minimum                        float64
#  144  ureacreat_ratio__sum_values          float64
#  145  ureacreat_ratio__median              float64
#  146  ureacreat_ratio__mean                float64
#  147  ureacreat_ratio__length              float64
#  148  ureacreat_ratio__standard_deviation  float64
#  149  ureacreat_ratio__variance            float64
#  150  ureacreat_ratio__root_mean_square    float64
#  151  ureacreat_ratio__maximum             float64
#  152  ureacreat_ratio__minimum             float64
#  153  wcc__sum_values                      float64
#  154  wcc__median                          float64
#  155  wcc__mean                            float64
#  156  wcc__length                          float64
#  157  wcc__standard_deviation              float64
#  158  wcc__variance                        float64
#  159  wcc__root_mean_square                float64
#  160  wcc__maximum                         float64
#  161  wcc__minimum                         float64
#  162  magnesium__sum_values                float64
#  163  magnesium__median                    float64
#  164  magnesium__mean                      float64
#  165  magnesium__length                    float64
#  166  magnesium__standard_deviation        float64
#  167  magnesium__variance                  float64
#  168  magnesium__root_mean_square          float64
#  169  magnesium__maximum                   float64
#  170  magnesium__minimum                   float64
#  171  alt__sum_values                      float64
#  172  alt__median                          float64
#  173  alt__mean                            float64
#  174  alt__length                          float64
#  175  alt__standard_deviation              float64
#  176  alt__variance                        float64
#  177  alt__root_mean_square                float64
#  178  alt__maximum                         float64
#  179  alt__minimum                         float64
#  180  basophils__sum_values                float64
#  181  basophils__median                    float64
#  182  basophils__mean                      float64
#  183  basophils__length                    float64
#  184  basophils__standard_deviation        float64
#  185  basophils__variance                  float64
#  186  basophils__root_mean_square          float64
#  187  basophils__maximum                   float64
#  188  basophils__minimum                   float64
#  189  bicarbonate__sum_values              float64
#  190  bicarbonate__median                  float64
#  191  bicarbonate__mean                    float64
#  192  bicarbonate__length                  float64
#  193  bicarbonate__standard_deviation      float64
#  194  bicarbonate__variance                float64
#  195  bicarbonate__root_mean_square        float64
#  196  bicarbonate__maximum                 float64
#  197  bicarbonate__minimum                 float64
#  198  bilirubin__sum_values                float64
#  199  bilirubin__median                    float64
#  200  bilirubin__mean                      float64
#  201  bilirubin__length                    float64
#  202  bilirubin__standard_deviation        float64
#  203  bilirubin__variance                  float64
#  204  bilirubin__root_mean_square          float64
#  205  bilirubin__maximum                   float64
#  206  bilirubin__minimum                   float64
#  207  eosinophils__sum_values              float64
#  208  eosinophils__median                  float64
#  209  eosinophils__mean                    float64
#  210  eosinophils__length                  float64
#  211  eosinophils__standard_deviation      float64
#  212  eosinophils__variance                float64
#  213  eosinophils__root_mean_square        float64
#  214  eosinophils__maximum                 float64
#  215  eosinophils__minimum                 float64
#  216  ggt__sum_values                      float64
#  217  ggt__median                          float64
#  218  ggt__mean                            float64
#  219  ggt__length                          float64
#  220  ggt__standard_deviation              float64
#  221  ggt__variance                        float64
#  222  ggt__root_mean_square                float64
#  223  ggt__maximum                         float64
#  224  ggt__minimum                         float64
#  225  globulin__sum_values                 float64
#  226  globulin__median                     float64
#  227  globulin__mean                       float64
#  228  globulin__length                     float64
#  229  globulin__standard_deviation         float64
#  230  globulin__variance                   float64
#  231  globulin__root_mean_square           float64
#  232  globulin__maximum                    float64
#  233  globulin__minimum                    float64
#  234  haematocrit__sum_values              float64
#  235  haematocrit__median                  float64
#  236  haematocrit__mean                    float64
#  237  haematocrit__length                  float64
#  238  haematocrit__standard_deviation      float64
#  239  haematocrit__variance                float64
#  240  haematocrit__root_mean_square        float64
#  241  haematocrit__maximum                 float64
#  242  haematocrit__minimum                 float64
#  243  lymphocytes__sum_values              float64
#  244  lymphocytes__median                  float64
#  245  lymphocytes__mean                    float64
#  246  lymphocytes__length                  float64
#  247  lymphocytes__standard_deviation      float64
#  248  lymphocytes__variance                float64
#  249  lymphocytes__root_mean_square        float64
#  250  lymphocytes__maximum                 float64
#  251  lymphocytes__minimum                 float64
#  252  mch__sum_values                      float64
#  253  mch__median                          float64
#  254  mch__mean                            float64
#  255  mch__length                          float64
#  256  mch__standard_deviation              float64
#  257  mch__variance                        float64
#  258  mch__root_mean_square                float64
#  259  mch__maximum                         float64
#  260  mch__minimum                         float64
#  261  mchc__sum_values                     float64
#  262  mchc__median                         float64
#  263  mchc__mean                           float64
#  264  mchc__length                         float64
#  265  mchc__standard_deviation             float64
#  266  mchc__variance                       float64
#  267  mchc__root_mean_square               float64
#  268  mchc__maximum                        float64
#  269  mchc__minimum                        float64
#  270  mcv__sum_values                      float64
#  271  mcv__median                          float64
#  272  mcv__mean                            float64
#  273  mcv__length                          float64
#  274  mcv__standard_deviation              float64
#  275  mcv__variance                        float64
#  276  mcv__root_mean_square                float64
#  277  mcv__maximum                         float64
#  278  mcv__minimum                         float64
#  279  monocytes__sum_values                float64
#  280  monocytes__median                    float64
#  281  monocytes__mean                      float64
#  282  monocytes__length                    float64
#  283  monocytes__standard_deviation        float64
#  284  monocytes__variance                  float64
#  285  monocytes__root_mean_square          float64
#  286  monocytes__maximum                   float64
#  287  monocytes__minimum                   float64
#  288  neutrophils__sum_values              float64
#  289  neutrophils__median                  float64
#  290  neutrophils__mean                    float64
#  291  neutrophils__length                  float64
#  292  neutrophils__standard_deviation      float64
#  293  neutrophils__variance                float64
#  294  neutrophils__root_mean_square        float64
#  295  neutrophils__maximum                 float64
#  296  neutrophils__minimum                 float64
#  297  protein__sum_values                  float64
#  298  protein__median                      float64
#  299  protein__mean                        float64
#  300  protein__length                      float64
#  301  protein__standard_deviation          float64
#  302  protein__variance                    float64
#  303  protein__root_mean_square            float64
#  304  protein__maximum                     float64
#  305  protein__minimum                     float64
#  306  rbc__sum_values                      float64
#  307  rbc__median                          float64
#  308  rbc__mean                            float64
#  309  rbc__length                          float64
#  310  rbc__standard_deviation              float64
#  311  rbc__variance                        float64
#  312  rbc__root_mean_square                float64
#  313  rbc__maximum                         float64
#  314  rbc__minimum                         float64
#  315  rdw__sum_values                      float64
#  316  rdw__median                          float64
#  317  rdw__mean                            float64
#  318  rdw__length                          float64
#  319  rdw__standard_deviation              float64
#  320  rdw__variance                        float64
#  321  rdw__root_mean_square                float64
#  322  rdw__maximum                         float64
#  323  rdw__minimum                         float64
#  324  sit_dia__sum_values                  float64
#  325  sit_dia__median                      float64
#  326  sit_dia__mean                        float64
#  327  sit_dia__length                      float64
#  328  sit_dia__standard_deviation          float64
#  329  sit_dia__variance                    float64
#  330  sit_dia__root_mean_square            float64
#  331  sit_dia__maximum                     float64
#  332  sit_dia__minimum                     float64
#  333  sit_sys__sum_values                  float64
#  334  sit_sys__median                      float64
#  335  sit_sys__mean                        float64
#  336  sit_sys__length                      float64
#  337  sit_sys__standard_deviation          float64
#  338  sit_sys__variance                    float64
#  339  sit_sys__root_mean_square            float64
#  340  sit_sys__maximum                     float64
#  341  sit_sys__minimum                     float64
#  342  sta_dia__sum_values                  float64
#  343  sta_dia__median                      float64
#  344  sta_dia__mean                        float64
#  345  sta_dia__length                      float64
#  346  sta_dia__standard_deviation          float64
#  347  sta_dia__variance                    float64
#  348  sta_dia__root_mean_square            float64
#  349  sta_dia__maximum                     float64
#  350  sta_dia__minimum                     float64
#  351  sta_sys__sum_values                  float64
#  352  sta_sys__median                      float64
#  353  sta_sys__mean                        float64
#  354  sta_sys__length                      float64
#  355  sta_sys__standard_deviation          float64
#  356  sta_sys__variance                    float64
#  357  sta_sys__root_mean_square            float64
#  358  sta_sys__maximum                     float64
#  359  sta_sys__minimum                     float64
#  360  weight__sum_values                   float64
#  361  weight__median                       float64
#  362  weight__mean                         float64
#  363  weight__length                       float64
#  364  weight__standard_deviation           float64
#  365  weight__variance                     float64
#  366  weight__root_mean_square             float64
#  367  weight__maximum                      float64
#  368  weight__minimum                      float64
#  369  aki_1                                float64
#  370  aki_2                                float64
#  371  aki_3                                float64
#  372  htn                                  category
#  373  dkd                                  category
#  374  gn                                   category
#  375  gender                               category
#  376  value_egfr_init                      float64
#  377  age.init                             int32
# dtypes: category(4), float64(373), int32(1)
# memory usage: 10.6 MB

# %%
y_mapped = y.map({'non_eskd':'no', 'eskd':'yes'})
y_mapped
# Out:
# id
# 3916     no
# 3918     no
# 3921     no
# 3924     no
# 3930     no
#          ..
# 23771    no
# 23775    no
# 23780    no
# 23823    no
# 23864    no
# Name: cat7, Length: 3708, dtype: category
# Categories (2, object): ['yes', 'no']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_mapped, test_size=0.3, stratify=y_mapped, random_state=random_state)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2595, 378), (1113, 378), (2595,), (1113,))

# %%
lab_encode = LabelEncoder()
y_train = lab_encode.fit_transform(y_train)
y_test = lab_encode.transform(y_test)

# %%
unique_values, counts = np.unique(y_train, return_counts=True)
ratio = dict(zip(unique_values, counts))
ratio
imbalance_ratio = ratio[0] / ratio[1]
imbalance_ratio
# Out:
# 7.2907348242811505

# %%
category_cols = list(X_train.select_dtypes(include='category').columns)
numeric_cols = list(X_train.select_dtypes(include=['int', 'float']).columns)
one_hot = OneHotEncoder(handle_unknown='ignore')
num_imputer = KNNImputer(n_neighbors=5)
len(category_cols), len(numeric_cols)
# Out:
# (4, 374)

# %%
preprocess = ColumnTransformer([('num_imputing', num_imputer, numeric_cols), ('cat_encoder', one_hot, category_cols)], remainder='passthrough')
X_train_processed = preprocess.fit_transform(X_train)
X_train_processed.shape
# Out:
# invalid value encountered in reduce
# invalid value encountered in reduce
# invalid value encountered in reduce
# invalid value encountered in reduce
# (2595, 389)

# %%
X_test_processed = preprocess.transform(X_test)
# Out:
# invalid value encountered in reduce
# invalid value encountered in reduce
# invalid value encountered in reduce

# %%
xgb_class = xgb.XGBClassifier(n_jobs=-1, random_state = random_state, n_estimators=1000, use_label_encoder=False, eval_metric='logloss', scale_pos_weight=imbalance_ratio)
sampler = SMOTETomek(sampling_strategy=0.5, random_state=random_state)
steps = [('resampling', sampler), ('model', xgb_class)]
pipeline = Pipeline(steps=steps)

# %%
pipeline.fit(X_train_processed, y_train)
# Out:
# Pipeline(steps=[('resampling',
#                  SMOTETomek(random_state=7, sampling_strategy=0.5)),
#                 ('model',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=1000,
#                                n_jobs=-1, num_parallel_tree=1, random_state=7,
#                                reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=7.2907348242811505, subsample=1,
#                                tree_method='exact', use_label_encoder=False,
#                                validate_parameters=1, verbosity=None))])

# %%
y_pred = pipeline.predict(X_test_processed)

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[934,  45],
#        [ 71,  63]])

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.7120919915234857

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       979
#            1       0.58      0.47      0.52       134
#
#     accuracy                           0.90      1113
#    macro avg       0.76      0.71      0.73      1113
# weighted avg       0.89      0.90      0.89      1113

# %%
print(matthews_corrcoef(y_test, y_pred))
# Out:
# 0.46634046587700295

# %%
importance = pipeline.named_steps['model'].feature_importances_
importance.shape, type(importance)
# Out:
# ((389,), numpy.ndarray)

# %%
category_label = list(preprocess.named_transformers_['cat_encoder'].get_feature_names(category_cols))
feature_label = numeric_cols + category_label

# %%
pd.set_option('display.max_rows', 400)
eval_df = pd.DataFrame({'label': feature_label, 'importance_value': importance})
eval_df.sort_values(by='importance_value', ascending=False).head(100)
# Out:
#                                label  importance_value
# 56                  creatinine__mean          0.159502
# 378                          gn_anca          0.061471
# 3                    albumin__length          0.027427
# 376                          dkd_dkd          0.024637
# 65                        egfr__mean          0.022795
# 87     haemoglobin__root_mean_square          0.022717
# 55                creatinine__median          0.014817
# 380                          gn_igan          0.014383
# 28            caphos_product__median          0.013678
# 213    eosinophils__root_mean_square          0.013490
# 311                    rbc__variance          0.010618
# 58    creatinine__standard_deviation          0.010612
# 142                    urea__maximum          0.009444
# 316                      rdw__median          0.009195
# 243          lymphocytes__sum_values          0.007935
# 281                  monocytes__mean          0.007755
# 7                   albumin__maximum          0.007659
# 67          egfr__standard_deviation          0.007338
# 374                          htn_htn          0.006913
# 265         mchc__standard_deviation          0.006872
# 15         alkphos__root_mean_square          0.006845
# 88              haemoglobin__maximum          0.006684
# 199                bilirubin__median          0.006380
# 29              caphos_product__mean          0.006266
# 284              monocytes__variance          0.006143
# 202    bilirubin__standard_deviation          0.006073
# 279            monocytes__sum_values          0.005990
# 271                      mcv__median          0.005944
# 234          haematocrit__sum_values          0.005798
# 262                     mchc__median          0.005772
# 6          albumin__root_mean_square          0.005617
# 333              sit_sys__sum_values          0.005278
# 114      potassium__root_mean_square          0.005202
# 385                            gn_no          0.005169
# 232                globulin__maximum          0.005152
# 260                     mch__minimum          0.005083
# 25                  calcium__maximum          0.005051
# 143                    urea__minimum          0.005016
# 141           urea__root_mean_square          0.004932
# 247  lymphocytes__standard_deviation          0.004838
# 346      sta_dia__standard_deviation          0.004741
# 214             eosinophils__maximum          0.004693
# 69            egfr__root_mean_square          0.004686
# 289              neutrophils__median          0.004529
# 48               cholesterol__length          0.004438
# 200                  bilirubin__mean          0.004370
# 373                         age.init          0.004303
# 350                 sta_dia__minimum          0.004220
# 263                       mchc__mean          0.004214
# 359                 sta_sys__minimum          0.004191
# 83                 haemoglobin__mean          0.004178
# 341                 sit_sys__minimum          0.004160
# 123         sodium__root_mean_square          0.004126
# 62               creatinine__minimum          0.004105
# 109                potassium__median          0.004085
# 215             eosinophils__minimum          0.004067
# 313                     rbc__maximum          0.004050
# 35           caphos_product__minimum          0.004006
# 32          caphos_product__variance          0.004000
# 363                   weight__length          0.003908
# 91                 phosphate__median          0.003891
# 217                      ggt__median          0.003891
# 37                  chloride__median          0.003728
# 218                        ggt__mean          0.003714
# 241             haematocrit__maximum          0.003523
# 189          bicarbonate__sum_values          0.003523
# 134           triglycerides__minimum          0.003362
# 14                 alkphos__variance          0.003309
# 310          rbc__standard_deviation          0.003264
# 334                  sit_sys__median          0.003242
# 52              cholesterol__maximum          0.003227
# 207          eosinophils__sum_values          0.003225
# 328      sit_dia__standard_deviation          0.003030
# 355      sta_sys__standard_deviation          0.002994
# 22       calcium__standard_deviation          0.002950
# 136                     urea__median          0.002923
# 82               haemoglobin__median          0.002908
# 64                      egfr__median          0.002861
# 140                   urea__variance          0.002829
# 254                        mch__mean          0.002828
# 303        protein__root_mean_square          0.002775
# 360               weight__sum_values          0.002760
# 18               calcium__sum_values          0.002738
# 106                platelet__maximum          0.002736
# 349                 sta_dia__maximum          0.002732
# 212            eosinophils__variance          0.002719
# 384                       gn_mp/mcgn          0.002710
# 126        triglycerides__sum_values          0.002651
# 0                albumin__sum_values          0.002632
# 79                  glucose__maximum          0.002623
# 351              sta_sys__sum_values          0.002619
# 367                  weight__maximum          0.002602
# 204      bilirubin__root_mean_square          0.002549
# 164                  magnesium__mean          0.002541
# 61               creatinine__maximum          0.002528
# 322                     rdw__maximum          0.002501
# 59              creatinine__variance          0.002494
# 242             haematocrit__minimum          0.002486
# 192              bicarbonate__length          0.002472
# 63                  egfr__sum_values          0.002460

# %%
xgb_class = xgb.XGBClassifier(n_jobs=-1, random_state = random_state, n_estimators=1000, use_label_encoder=False, eval_metric='logloss', scale_pos_weight=1.5*imbalance_ratio)
sampler = SMOTETomek(sampling_strategy=0.5, random_state=random_state)
steps = [('resampling', sampler), ('model', xgb_class)]
pipeline = Pipeline(steps=steps)

# %%
pipeline.fit(X_train_processed, y_train)
# Out:
# Pipeline(steps=[('resampling',
#                  SMOTETomek(random_state=7, sampling_strategy=0.5)),
#                 ('model',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=1000,
#                                n_jobs=-1, num_parallel_tree=1, random_state=7,
#                                reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=10.936102236421725, subsample=1,
#                                tree_method='exact', use_label_encoder=False,
#                                validate_parameters=1, verbosity=None))])

# %%
y_pred = pipeline.predict(X_test_processed)

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[931,  48],
#        [ 68,  66]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       979
#            1       0.58      0.49      0.53       134
#
#     accuracy                           0.90      1113
#    macro avg       0.76      0.72      0.74      1113
# weighted avg       0.89      0.90      0.89      1113

# %%
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.47600304522977643
